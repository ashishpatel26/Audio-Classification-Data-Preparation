# %% [markdown]
# # load the zip file and unzip and before check the GPU

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# import dependencies
import requests, zipfile, io
from glob import glob
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
import numpy as np
from tqdm import tqdm
import cv2
import pandas as pd
seed = 7
import pandas as pd
np.random.seed(seed)
import os

# %%
zip_file_url = 'https://github.com/karoldvl/ESC-50/archive/master.zip' # link: ESC-50 Datset

# %%
if not os.path.exists('sound'):
    os.makedirs('sound')

# %%
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall('sound/')
z.close()

# %%
glob('sound/ESC-50-master/audio/*')
# Out:
# ['sound/ESC-50-master/audio/3-188390-A-6.wav',
#  'sound/ESC-50-master/audio/4-144085-A-16.wav',
#  'sound/ESC-50-master/audio/5-207836-C-29.wav',
#  'sound/ESC-50-master/audio/3-203377-A-39.wav',
#  'sound/ESC-50-master/audio/2-152964-A-31.wav',
#  'sound/ESC-50-master/audio/3-102583-B-49.wav',
#  'sound/ESC-50-master/audio/3-119120-A-48.wav',
#  'sound/ESC-50-master/audio/1-172649-F-40.wav',
#  'sound/ESC-50-master/audio/4-144083-A-16.wav',
#  'sound/ESC-50-master/audio/1-7974-A-49.wav',
#  'sound/ESC-50-master/audio/2-114280-A-0.wav',
#  'sound/ESC-50-master/audio/3-130998-B-28.wav',
#  'sound/ESC-50-master/audio/2-88724-A-38.wav',
#  'sound/ESC-50-master/audio/5-262641-A-15.wav',
#  'sound/ESC-50-master/audio/1-23094-B-15.wav',
#  'sound/ESC-50-master/audio/4-182613-B-11.wav',
#  'sound/ESC-50-master/audio/5-186924-A-12.wav',
#  'sound/ESC-50-master/audio/1-31836-B-4.wav',
#  'sound/ESC-50-master/audio/3-203373-A-39.wav',
#  'sound/ESC-50-master/audio/4-213193-A-29.wav',
#  'sound/ESC-50-master/audio/4-161579-A-40.wav',
#  'sound/ESC-50-master/audio/5-235593-A-23.wav',
#  'sound/ESC-50-master/audio/1-52266-A-24.wav',
#  'sound/ESC-50-master/audio/4-133047-A-5.wav',
#  'sound/ESC-50-master/audio/5-248341-B-6.wav',
#  'sound/ESC-50-master/audio/3-146033-A-13.wav',
#  'sound/ESC-50-master/audio/4-197871-A-15.wav',
#  'sound/ESC-50-master/audio/5-238021-A-35.wav',
#  'sound/ESC-50-master/audio/1-50688-A-17.wav',
#  'sound/ESC-50-master/audio/4-120160-A-5.wav',
#  'sound/ESC-50-master/audio/2-108767-B-9.wav',
#  'sound/ESC-50-master/audio/3-180256-A-0.wav',
#  'sound/ESC-50-master/audio/1-40730-A-1.wav',
#  'sound/ESC-50-master/audio/4-212604-A-15.wav',
#  'sound/ESC-50-master/audio/1-103298-A-9.wav',
#  'sound/ESC-50-master/audio/3-100018-A-18.wav',
#  'sound/ESC-50-master/audio/5-212059-A-36.wav',
#  'sound/ESC-50-master/audio/5-263491-A-25.wav',
#  'sound/ESC-50-master/audio/3-100024-A-27.wav',
#  'sound/ESC-50-master/audio/3-103599-B-25.wav',
#  'sound/ESC-50-master/audio/5-242490-A-14.wav',
#  'sound/ESC-50-master/audio/4-194754-A-0.wav',
#  'sound/ESC-50-master/audio/2-52001-A-28.wav',
#  'sound/ESC-50-master/audio/1-52290-A-30.wav',
#  'sound/ESC-50-master/audio/5-160614-A-48.wav',
#  'sound/ESC-50-master/audio/3-249913-A-25.wav',
#  'sound/ESC-50-master/audio/3-94355-A-33.wav',
#  'sound/ESC-50-master/audio/3-98869-A-46.wav',
#  'sound/ESC-50-master/audio/4-169127-B-41.wav',
#  'sound/ESC-50-master/audio/3-157487-A-10.wav',
#  'sound/ESC-50-master/audio/4-174860-A-3.wav',
#  'sound/ESC-50-master/audio/5-215179-A-13.wav',
#  'sound/ESC-50-master/audio/5-253101-B-49.wav',
#  'sound/ESC-50-master/audio/1-52323-A-24.wav',
#  'sound/ESC-50-master/audio/4-188878-A-30.wav',
#  'sound/ESC-50-master/audio/2-83536-A-27.wav',
#  'sound/ESC-50-master/audio/3-119120-E-48.wav',
#  'sound/ESC-50-master/audio/2-117330-A-28.wav',
#  'sound/ESC-50-master/audio/1-81001-B-30.wav',
#  'sound/ESC-50-master/audio/4-209698-A-37.wav',
#  'sound/ESC-50-master/audio/4-195497-A-11.wav',
#  'sound/ESC-50-master/audio/3-130330-A-22.wav',
#  'sound/ESC-50-master/audio/5-213802-A-12.wav',
#  'sound/ESC-50-master/audio/4-182314-B-7.wav',
#  'sound/ESC-50-master/audio/5-233312-A-28.wav',
#  'sound/ESC-50-master/audio/3-140774-A-10.wav',
#  'sound/ESC-50-master/audio/3-164688-A-38.wav',
#  'sound/ESC-50-master/audio/2-81970-B-7.wav',
#  'sound/ESC-50-master/audio/2-82367-A-10.wav',
#  'sound/ESC-50-master/audio/1-26143-A-21.wav',
#  'sound/ESC-50-master/audio/3-170851-A-31.wav',
#  'sound/ESC-50-master/audio/2-52001-B-28.wav',
#  'sound/ESC-50-master/audio/1-51035-A-16.wav',
#  'sound/ESC-50-master/audio/3-65748-A-12.wav',
#  'sound/ESC-50-master/audio/4-164243-A-26.wav',
#  'sound/ESC-50-master/audio/3-92637-A-18.wav',
#  'sound/ESC-50-master/audio/3-145487-A-24.wav',
#  'sound/ESC-50-master/audio/3-166546-B-34.wav',
#  'sound/ESC-50-master/audio/4-198962-B-25.wav',
#  'sound/ESC-50-master/audio/5-209992-B-44.wav',
#  'sound/ESC-50-master/audio/4-208021-A-1.wav',
#  'sound/ESC-50-master/audio/5-236288-A-28.wav',
#  'sound/ESC-50-master/audio/5-218494-A-22.wav',
#  'sound/ESC-50-master/audio/4-204777-A-39.wav',
#  'sound/ESC-50-master/audio/4-157611-A-41.wav',
#  'sound/ESC-50-master/audio/4-161519-A-19.wav',
#  'sound/ESC-50-master/audio/5-212736-A-17.wav',
#  'sound/ESC-50-master/audio/2-60180-B-49.wav',
#  'sound/ESC-50-master/audio/4-204683-A-31.wav',
#  'sound/ESC-50-master/audio/5-215005-A-32.wav',
#  'sound/ESC-50-master/audio/1-59513-A-0.wav',
#  'sound/ESC-50-master/audio/1-24524-C-19.wav',
#  'sound/ESC-50-master/audio/3-152594-A-30.wav',
#  'sound/ESC-50-master/audio/2-80313-A-28.wav',
#  'sound/ESC-50-master/audio/1-30709-C-23.wav',
#  'sound/ESC-50-master/audio/5-198278-C-7.wav',
#  'sound/ESC-50-master/audio/1-15689-B-4.wav',
#  'sound/ESC-50-master/audio/1-69165-A-34.wav',
#  'sound/ESC-50-master/audio/2-87282-A-34.wav',
#  'sound/ESC-50-master/audio/1-72695-A-26.wav',
#  'sound/ESC-50-master/audio/5-248341-A-6.wav',
#  'sound/ESC-50-master/audio/3-177083-A-22.wav',
#  'sound/ESC-50-master/audio/5-180156-C-43.wav',
#  'sound/ESC-50-master/audio/4-165845-B-45.wav',
#  'sound/ESC-50-master/audio/5-198278-A-7.wav',
#  'sound/ESC-50-master/audio/3-203374-A-39.wav',
#  'sound/ESC-50-master/audio/3-159445-B-45.wav',
#  'sound/ESC-50-master/audio/3-159347-A-36.wav',
#  'sound/ESC-50-master/audio/2-106073-A-36.wav',
#  'sound/ESC-50-master/audio/3-71964-C-4.wav',
#  'sound/ESC-50-master/audio/2-119161-A-8.wav',
#  'sound/ESC-50-master/audio/4-140034-A-46.wav',
#  'sound/ESC-50-master/audio/2-122763-B-29.wav',
#  'sound/ESC-50-master/audio/3-151206-A-23.wav',
#  'sound/ESC-50-master/audio/5-235507-A-44.wav',
#  'sound/ESC-50-master/audio/2-160888-A-47.wav',
#  'sound/ESC-50-master/audio/3-146964-A-5.wav',
#  'sound/ESC-50-master/audio/5-244459-A-28.wav',
#  'sound/ESC-50-master/audio/5-179865-A-43.wav',
#  'sound/ESC-50-master/audio/2-109316-A-32.wav',
#  'sound/ESC-50-master/audio/5-259180-A-15.wav',
#  'sound/ESC-50-master/audio/3-140323-A-29.wav',
#  'sound/ESC-50-master/audio/2-135860-A-49.wav',
#  'sound/ESC-50-master/audio/2-117271-A-0.wav',
#  'sound/ESC-50-master/audio/5-187444-A-33.wav',
#  'sound/ESC-50-master/audio/3-136608-A-16.wav',
#  'sound/ESC-50-master/audio/2-114254-A-30.wav',
#  'sound/ESC-50-master/audio/4-200330-B-6.wav',
#  'sound/ESC-50-master/audio/3-152007-E-20.wav',
#  'sound/ESC-50-master/audio/4-188191-C-29.wav',
#  'sound/ESC-50-master/audio/2-110613-A-13.wav',
#  'sound/ESC-50-master/audio/5-244178-A-32.wav',
#  'sound/ESC-50-master/audio/1-19898-C-41.wav',
#  'sound/ESC-50-master/audio/3-120644-A-12.wav',
#  'sound/ESC-50-master/audio/1-28135-A-11.wav',
#  'sound/ESC-50-master/audio/3-143933-A-38.wav',
#  'sound/ESC-50-master/audio/2-117795-B-3.wav',
#  'sound/ESC-50-master/audio/1-49098-A-35.wav',
#  'sound/ESC-50-master/audio/5-218196-A-27.wav',
#  'sound/ESC-50-master/audio/3-142605-A-21.wav',
#  'sound/ESC-50-master/audio/1-32373-B-35.wav',
#  'sound/ESC-50-master/audio/3-138212-A-45.wav',
#  'sound/ESC-50-master/audio/1-137296-A-16.wav',
#  'sound/ESC-50-master/audio/2-70280-A-18.wav',
#  'sound/ESC-50-master/audio/1-34497-A-14.wav',
#  'sound/ESC-50-master/audio/3-145382-A-1.wav',
#  'sound/ESC-50-master/audio/1-23996-B-35.wav',
#  'sound/ESC-50-master/audio/3-124600-A-19.wav',
#  'sound/ESC-50-master/audio/2-109371-C-16.wav',
#  'sound/ESC-50-master/audio/3-182025-A-30.wav',
#  'sound/ESC-50-master/audio/3-110913-B-7.wav',
#  'sound/ESC-50-master/audio/1-22694-A-20.wav',
#  'sound/ESC-50-master/audio/5-189212-A-12.wav',
#  'sound/ESC-50-master/audio/4-90014-B-42.wav',
#  'sound/ESC-50-master/audio/4-186938-A-44.wav',
#  'sound/ESC-50-master/audio/2-117616-A-48.wav',
#  'sound/ESC-50-master/audio/3-158476-A-12.wav',
#  'sound/ESC-50-master/audio/1-50623-A-15.wav',
#  'sound/ESC-50-master/audio/2-81112-A-34.wav',
#  'sound/ESC-50-master/audio/3-145387-A-29.wav',
#  'sound/ESC-50-master/audio/5-179294-A-46.wav',
#  'sound/ESC-50-master/audio/5-233787-A-7.wav',
#  'sound/ESC-50-master/audio/1-53663-A-24.wav',
#  'sound/ESC-50-master/audio/1-22694-B-20.wav',
#  'sound/ESC-50-master/audio/3-144259-A-29.wav',
#  'sound/ESC-50-master/audio/3-153444-A-32.wav',
#  'sound/ESC-50-master/audio/5-222041-A-9.wav',
#  'sound/ESC-50-master/audio/1-54918-B-14.wav',
#  'sound/ESC-50-master/audio/2-102567-C-35.wav',
#  'sound/ESC-50-master/audio/1-31748-A-21.wav',
#  'sound/ESC-50-master/audio/5-256512-A-30.wav',
#  'sound/ESC-50-master/audio/3-123086-A-28.wav',
#  'sound/ESC-50-master/audio/1-59102-A-13.wav',
#  'sound/ESC-50-master/audio/2-125966-A-11.wav',
#  'sound/ESC-50-master/audio/2-133863-A-11.wav',
#  'sound/ESC-50-master/audio/2-209471-A-25.wav',
#  'sound/ESC-50-master/audio/1-39937-A-28.wav',
#  'sound/ESC-50-master/audio/3-145774-A-12.wav',
#  'sound/ESC-50-master/audio/1-76831-D-42.wav',
#  'sound/ESC-50-master/audio/2-130978-A-21.wav',
#  'sound/ESC-50-master/audio/4-202298-A-31.wav',
#  'sound/ESC-50-master/audio/4-160036-B-33.wav',
#  'sound/ESC-50-master/audio/5-259169-A-5.wav',
#  'sound/ESC-50-master/audio/4-175025-A-34.wav',
#  'sound/ESC-50-master/audio/1-58846-A-34.wav',
#  'sound/ESC-50-master/audio/4-156827-A-46.wav',
#  'sound/ESC-50-master/audio/2-128465-B-43.wav',
#  'sound/ESC-50-master/audio/4-207116-A-23.wav',
#  'sound/ESC-50-master/audio/1-50455-A-44.wav',
#  'sound/ESC-50-master/audio/2-32834-A-4.wav',
#  'sound/ESC-50-master/audio/5-188495-A-19.wav',
#  'sound/ESC-50-master/audio/5-160614-E-48.wav',
#  'sound/ESC-50-master/audio/1-68734-A-34.wav',
#  'sound/ESC-50-master/audio/2-73544-A-27.wav',
#  'sound/ESC-50-master/audio/1-115545-C-48.wav',
#  'sound/ESC-50-master/audio/1-77160-A-3.wav',
#  'sound/ESC-50-master/audio/4-213915-A-3.wav',
#  'sound/ESC-50-master/audio/2-188822-C-40.wav',
#  'sound/ESC-50-master/audio/3-216281-A-39.wav',
#  'sound/ESC-50-master/audio/1-77241-A-3.wav',
#  'sound/ESC-50-master/audio/2-102568-A-35.wav',
#  'sound/ESC-50-master/audio/1-17295-A-29.wav',
#  'sound/ESC-50-master/audio/2-39443-A-19.wav',
#  'sound/ESC-50-master/audio/2-59241-A-35.wav',
#  'sound/ESC-50-master/audio/2-85434-A-27.wav',
#  'sound/ESC-50-master/audio/2-70052-A-42.wav',
#  'sound/ESC-50-master/audio/5-234247-A-37.wav',
#  'sound/ESC-50-master/audio/4-195451-A-44.wav',
#  'sound/ESC-50-master/audio/5-234145-A-28.wav',
#  'sound/ESC-50-master/audio/4-182314-A-7.wav',
#  'sound/ESC-50-master/audio/3-141240-A-44.wav',
#  'sound/ESC-50-master/audio/2-69131-A-5.wav',
#  'sound/ESC-50-master/audio/1-40621-A-28.wav',
#  'sound/ESC-50-master/audio/2-72970-A-10.wav',
#  'sound/ESC-50-master/audio/1-115921-A-22.wav',
#  'sound/ESC-50-master/audio/5-103422-A-2.wav',
#  'sound/ESC-50-master/audio/5-177957-E-40.wav',
#  'sound/ESC-50-master/audio/3-135469-A-35.wav',
#  'sound/ESC-50-master/audio/2-262579-A-45.wav',
#  'sound/ESC-50-master/audio/4-196671-A-8.wav',
#  'sound/ESC-50-master/audio/4-151242-A-37.wav',
#  'sound/ESC-50-master/audio/4-119648-C-48.wav',
#  'sound/ESC-50-master/audio/5-243773-B-44.wav',
#  'sound/ESC-50-master/audio/4-130584-A-4.wav',
#  'sound/ESC-50-master/audio/1-155858-B-25.wav',
#  'sound/ESC-50-master/audio/5-251426-A-30.wav',
#  'sound/ESC-50-master/audio/2-78651-A-44.wav',
#  'sound/ESC-50-master/audio/1-47709-A-16.wav',
#  'sound/ESC-50-master/audio/1-53670-A-18.wav',
#  'sound/ESC-50-master/audio/4-147658-A-46.wav',
#  'sound/ESC-50-master/audio/5-235644-A-30.wav',
#  'sound/ESC-50-master/audio/5-232816-A-23.wav',
#  'sound/ESC-50-master/audio/1-208757-A-2.wav',
#  'sound/ESC-50-master/audio/4-187504-B-17.wav',
#  'sound/ESC-50-master/audio/2-125821-A-13.wav',
#  'sound/ESC-50-master/audio/4-145006-A-18.wav',
#  'sound/ESC-50-master/audio/3-185456-A-29.wav',
#  'sound/ESC-50-master/audio/5-117122-A-42.wav',
#  'sound/ESC-50-master/audio/5-204114-A-29.wav',
#  'sound/ESC-50-master/audio/5-209989-A-22.wav',
#  'sound/ESC-50-master/audio/5-250258-A-49.wav',
#  'sound/ESC-50-master/audio/2-110011-A-5.wav',
#  'sound/ESC-50-master/audio/1-34119-A-1.wav',
#  'sound/ESC-50-master/audio/3-139958-A-37.wav',
#  'sound/ESC-50-master/audio/5-177614-A-5.wav',
#  'sound/ESC-50-master/audio/3-62878-B-42.wav',
#  'sound/ESC-50-master/audio/1-42139-A-38.wav',
#  'sound/ESC-50-master/audio/2-43802-A-42.wav',
#  'sound/ESC-50-master/audio/3-149189-A-1.wav',
#  'sound/ESC-50-master/audio/3-159445-A-45.wav',
#  'sound/ESC-50-master/audio/4-167077-B-20.wav',
#  'sound/ESC-50-master/audio/1-54747-A-46.wav',
#  'sound/ESC-50-master/audio/5-184323-A-42.wav',
#  'sound/ESC-50-master/audio/1-54505-A-21.wav',
#  'sound/ESC-50-master/audio/3-163288-A-1.wav',
#  'sound/ESC-50-master/audio/5-263902-A-36.wav',
#  'sound/ESC-50-master/audio/5-223103-A-31.wav',
#  'sound/ESC-50-master/audio/2-84965-A-23.wav',
#  'sound/ESC-50-master/audio/4-188287-A-9.wav',
#  'sound/ESC-50-master/audio/2-87794-A-24.wav',
#  'sound/ESC-50-master/audio/2-82455-A-23.wav',
#  'sound/ESC-50-master/audio/2-141681-B-36.wav',
#  'sound/ESC-50-master/audio/1-208757-E-2.wav',
#  'sound/ESC-50-master/audio/2-66637-A-20.wav',
#  'sound/ESC-50-master/audio/2-39443-B-19.wav',
#  'sound/ESC-50-master/audio/1-29561-A-10.wav',
#  'sound/ESC-50-master/audio/3-203375-A-39.wav',
#  'sound/ESC-50-master/audio/3-251617-A-48.wav',
#  'sound/ESC-50-master/audio/2-87799-A-24.wav',
#  'sound/ESC-50-master/audio/5-261433-A-15.wav',
#  'sound/ESC-50-master/audio/2-106014-A-44.wav',
#  'sound/ESC-50-master/audio/5-194899-A-3.wav',
#  'sound/ESC-50-master/audio/1-50060-A-10.wav',
#  'sound/ESC-50-master/audio/5-201172-A-46.wav',
#  'sound/ESC-50-master/audio/4-132839-A-33.wav',
#  'sound/ESC-50-master/audio/5-243448-A-14.wav',
#  'sound/ESC-50-master/audio/1-62849-A-38.wav',
#  'sound/ESC-50-master/audio/4-251959-A-47.wav',
#  'sound/ESC-50-master/audio/4-180337-A-28.wav',
#  'sound/ESC-50-master/audio/5-179496-B-16.wav',
#  'sound/ESC-50-master/audio/4-144468-B-27.wav',
#  'sound/ESC-50-master/audio/2-109371-B-16.wav',
#  'sound/ESC-50-master/audio/2-103423-A-3.wav',
#  'sound/ESC-50-master/audio/3-187549-A-6.wav',
#  'sound/ESC-50-master/audio/1-110537-A-22.wav',
#  'sound/ESC-50-master/audio/3-155766-A-13.wav',
#  'sound/ESC-50-master/audio/3-158056-B-31.wav',
#  'sound/ESC-50-master/audio/5-216214-A-13.wav',
#  'sound/ESC-50-master/audio/4-174797-A-15.wav',
#  'sound/ESC-50-master/audio/3-155312-A-0.wav',
#  'sound/ESC-50-master/audio/1-17150-A-12.wav',
#  'sound/ESC-50-master/audio/2-57733-A-22.wav',
#  'sound/ESC-50-master/audio/5-250753-A-34.wav',
#  'sound/ESC-50-master/audio/1-62509-A-45.wav',
#  'sound/ESC-50-master/audio/4-123680-A-18.wav',
#  'sound/ESC-50-master/audio/3-118657-A-41.wav',
#  'sound/ESC-50-master/audio/5-199284-A-45.wav',
#  'sound/ESC-50-master/audio/2-209472-A-25.wav',
#  'sound/ESC-50-master/audio/1-46353-A-49.wav',
#  'sound/ESC-50-master/audio/5-169983-A-5.wav',
#  'sound/ESC-50-master/audio/3-129678-A-13.wav',
#  'sound/ESC-50-master/audio/2-124564-A-15.wav',
#  'sound/ESC-50-master/audio/1-260640-B-2.wav',
#  'sound/ESC-50-master/audio/3-127890-B-9.wav',
#  'sound/ESC-50-master/audio/2-106015-B-44.wav',
#  'sound/ESC-50-master/audio/2-84943-A-18.wav',
#  'sound/ESC-50-master/audio/5-198891-A-8.wav',
#  'sound/ESC-50-master/audio/2-158746-D-2.wav',
#  'sound/ESC-50-master/audio/4-119647-C-48.wav',
#  'sound/ESC-50-master/audio/1-187207-A-20.wav',
#  'sound/ESC-50-master/audio/4-157297-A-21.wav',
#  'sound/ESC-50-master/audio/3-117793-A-37.wav',
#  'sound/ESC-50-master/audio/2-146877-A-31.wav',
#  'sound/ESC-50-master/audio/1-103995-A-30.wav',
#  'sound/ESC-50-master/audio/1-155858-F-25.wav',
#  'sound/ESC-50-master/audio/4-150364-A-46.wav',
#  'sound/ESC-50-master/audio/1-75190-A-8.wav',
#  'sound/ESC-50-master/audio/4-125072-A-19.wav',
#  'sound/ESC-50-master/audio/5-263501-A-25.wav',
#  'sound/ESC-50-master/audio/3-155659-A-34.wav',
#  'sound/ESC-50-master/audio/5-185908-A-18.wav',
#  'sound/ESC-50-master/audio/4-223127-A-14.wav',
#  'sound/ESC-50-master/audio/5-214869-A-9.wav',
#  'sound/ESC-50-master/audio/3-164594-A-15.wav',
#  'sound/ESC-50-master/audio/2-81190-A-34.wav',
#  'sound/ESC-50-master/audio/3-164120-A-11.wav',
#  'sound/ESC-50-master/audio/2-71162-A-1.wav',
#  'sound/ESC-50-master/audio/5-221518-A-21.wav',
#  'sound/ESC-50-master/audio/3-119120-D-48.wav',
#  'sound/ESC-50-master/audio/2-92978-A-29.wav',
#  'sound/ESC-50-master/audio/4-161105-B-47.wav',
#  'sound/ESC-50-master/audio/1-79146-A-29.wav',
#  'sound/ESC-50-master/audio/1-62565-A-44.wav',
#  'sound/ESC-50-master/audio/1-18810-A-49.wav',
#  'sound/ESC-50-master/audio/4-198360-B-49.wav',
#  'sound/ESC-50-master/audio/3-174866-A-29.wav',
#  'sound/ESC-50-master/audio/1-54084-A-42.wav',
#  'sound/ESC-50-master/audio/3-185313-A-31.wav',
#  'sound/ESC-50-master/audio/1-115546-A-48.wav',
#  'sound/ESC-50-master/audio/3-51909-B-42.wav',
#  'sound/ESC-50-master/audio/2-141584-A-38.wav',
#  'sound/ESC-50-master/audio/1-61252-A-11.wav',
#  'sound/ESC-50-master/audio/1-100038-A-14.wav',
#  'sound/ESC-50-master/audio/3-155568-A-32.wav',
#  'sound/ESC-50-master/audio/5-217186-C-16.wav',
#  'sound/ESC-50-master/audio/4-201988-A-44.wav',
#  'sound/ESC-50-master/audio/2-50668-A-41.wav',
#  'sound/ESC-50-master/audio/2-104105-A-19.wav',
#  'sound/ESC-50-master/audio/5-207836-B-29.wav',
#  'sound/ESC-50-master/audio/2-139748-A-15.wav',
#  'sound/ESC-50-master/audio/5-238492-A-23.wav',
#  'sound/ESC-50-master/audio/2-141682-A-36.wav',
#  'sound/ESC-50-master/audio/5-198891-B-8.wav',
#  'sound/ESC-50-master/audio/1-56234-A-9.wav',
#  'sound/ESC-50-master/audio/5-195557-A-19.wav',
#  'sound/ESC-50-master/audio/3-164216-B-6.wav',
#  'sound/ESC-50-master/audio/4-201800-A-31.wav',
#  'sound/ESC-50-master/audio/4-188293-A-15.wav',
#  'sound/ESC-50-master/audio/5-221593-A-21.wav',
#  'sound/ESC-50-master/audio/3-156558-A-21.wav',
#  'sound/ESC-50-master/audio/1-46272-A-12.wav',
#  'sound/ESC-50-master/audio/1-254507-A-43.wav',
#  'sound/ESC-50-master/audio/5-103418-A-2.wav',
#  'sound/ESC-50-master/audio/1-19118-A-24.wav',
#  'sound/ESC-50-master/audio/3-253084-E-2.wav',
#  'sound/ESC-50-master/audio/1-18074-A-6.wav',
#  'sound/ESC-50-master/audio/3-154926-A-40.wav',
#  'sound/ESC-50-master/audio/2-99955-C-7.wav',
#  'sound/ESC-50-master/audio/2-54086-A-43.wav',
#  'sound/ESC-50-master/audio/1-33658-A-26.wav',
#  'sound/ESC-50-master/audio/2-106019-A-13.wav',
#  'sound/ESC-50-master/audio/4-167063-B-11.wav',
#  'sound/ESC-50-master/audio/1-43807-D-47.wav',
#  'sound/ESC-50-master/audio/3-151080-A-20.wav',
#  'sound/ESC-50-master/audio/3-138114-A-22.wav',
#  'sound/ESC-50-master/audio/1-45641-A-27.wav',
#  'sound/ESC-50-master/audio/4-161579-B-40.wav',
#  'sound/ESC-50-master/audio/3-126358-A-3.wav',
#  'sound/ESC-50-master/audio/1-30344-A-0.wav',
#  'sound/ESC-50-master/audio/2-78381-A-46.wav',
#  'sound/ESC-50-master/audio/3-134699-B-16.wav',
#  'sound/ESC-50-master/audio/2-70344-A-33.wav',
#  'sound/ESC-50-master/audio/3-115382-A-44.wav',
#  'sound/ESC-50-master/audio/1-36402-A-23.wav',
#  'sound/ESC-50-master/audio/2-68391-B-41.wav',
#  'sound/ESC-50-master/audio/1-24796-A-47.wav',
#  'sound/ESC-50-master/audio/4-232495-A-6.wav',
#  'sound/ESC-50-master/audio/4-159426-A-9.wav',
#  'sound/ESC-50-master/audio/2-95567-A-23.wav',
#  'sound/ESC-50-master/audio/1-7057-A-12.wav',
#  'sound/ESC-50-master/audio/5-253094-B-49.wav',
#  'sound/ESC-50-master/audio/2-141563-A-39.wav',
#  'sound/ESC-50-master/audio/3-155584-A-14.wav',
#  'sound/ESC-50-master/audio/2-72688-A-42.wav',
#  'sound/ESC-50-master/audio/3-160993-A-3.wav',
#  'sound/ESC-50-master/audio/4-204777-C-39.wav',
#  'sound/ESC-50-master/audio/4-184237-A-28.wav',
#  'sound/ESC-50-master/audio/2-82071-A-27.wav',
#  'sound/ESC-50-master/audio/2-56926-A-46.wav',
#  'sound/ESC-50-master/audio/1-60676-A-34.wav',
#  'sound/ESC-50-master/audio/1-137-A-32.wav',
#  'sound/ESC-50-master/audio/2-118817-A-32.wav',
#  'sound/ESC-50-master/audio/2-65747-A-12.wav',
#  'sound/ESC-50-master/audio/4-204115-A-39.wav',
#  'sound/ESC-50-master/audio/5-251963-A-47.wav',
#  'sound/ESC-50-master/audio/4-147240-A-2.wav',
#  'sound/ESC-50-master/audio/3-170312-A-31.wav',
#  'sound/ESC-50-master/audio/5-197121-A-45.wav',
#  'sound/ESC-50-master/audio/2-70366-A-33.wav',
#  'sound/ESC-50-master/audio/4-261068-A-30.wav',
#  'sound/ESC-50-master/audio/4-164661-B-12.wav',
#  'sound/ESC-50-master/audio/1-16746-A-15.wav',
#  'sound/ESC-50-master/audio/4-157611-B-41.wav',
#  'sound/ESC-50-master/audio/3-160119-A-15.wav',
#  'sound/ESC-50-master/audio/5-260433-A-39.wav',
#  'sound/ESC-50-master/audio/3-110913-A-7.wav',
#  'sound/ESC-50-master/audio/1-24524-B-19.wav',
#  'sound/ESC-50-master/audio/2-158746-A-2.wav',
#  'sound/ESC-50-master/audio/4-119648-B-48.wav',
#  'sound/ESC-50-master/audio/5-197446-A-7.wav',
#  'sound/ESC-50-master/audio/3-103401-D-33.wav',
#  'sound/ESC-50-master/audio/1-47250-A-41.wav',
#  'sound/ESC-50-master/audio/5-184871-A-24.wav',
#  'sound/ESC-50-master/audio/2-188822-B-40.wav',
#  'sound/ESC-50-master/audio/1-88807-A-39.wav',
#  'sound/ESC-50-master/audio/2-158746-B-2.wav',
#  'sound/ESC-50-master/audio/5-209698-A-38.wav',
#  'sound/ESC-50-master/audio/4-172500-C-27.wav',
#  'sound/ESC-50-master/audio/4-186935-A-44.wav',
#  'sound/ESC-50-master/audio/4-223125-A-14.wav',
#  'sound/ESC-50-master/audio/3-157615-A-10.wav',
#  'sound/ESC-50-master/audio/3-95698-A-5.wav',
#  'sound/ESC-50-master/audio/2-116400-A-0.wav',
#  'sound/ESC-50-master/audio/2-76408-A-22.wav',
#  'sound/ESC-50-master/audio/1-39901-A-11.wav',
#  'sound/ESC-50-master/audio/4-167063-C-11.wav',
#  'sound/ESC-50-master/audio/2-104105-B-19.wav',
#  'sound/ESC-50-master/audio/4-191246-B-7.wav',
#  'sound/ESC-50-master/audio/4-198360-C-49.wav',
#  'sound/ESC-50-master/audio/1-17124-A-43.wav',
#  'sound/ESC-50-master/audio/1-62594-A-32.wav',
#  'sound/ESC-50-master/audio/5-207836-A-29.wav',
#  'sound/ESC-50-master/audio/1-31251-B-6.wav',
#  'sound/ESC-50-master/audio/5-208030-A-0.wav',
#  'sound/ESC-50-master/audio/3-162786-A-13.wav',
#  'sound/ESC-50-master/audio/4-161100-A-47.wav',
#  'sound/ESC-50-master/audio/1-28808-A-43.wav',
#  'sound/ESC-50-master/audio/5-215172-A-13.wav',
#  'sound/ESC-50-master/audio/2-52085-B-4.wav',
#  'sound/ESC-50-master/audio/4-213915-C-3.wav',
#  'sound/ESC-50-master/audio/2-110010-A-5.wav',
#  'sound/ESC-50-master/audio/4-250864-A-8.wav',
#  'sound/ESC-50-master/audio/2-64963-A-15.wav',
#  'sound/ESC-50-master/audio/5-263831-B-6.wav',
#  'sound/ESC-50-master/audio/1-69641-A-3.wav',
#  'sound/ESC-50-master/audio/2-106015-A-44.wav',
#  'sound/ESC-50-master/audio/4-171706-A-23.wav',
#  'sound/ESC-50-master/audio/2-54961-A-23.wav',
#  'sound/ESC-50-master/audio/1-208757-B-2.wav',
#  'sound/ESC-50-master/audio/4-182034-A-30.wav',
#  'sound/ESC-50-master/audio/1-76831-C-42.wav',
#  'sound/ESC-50-master/audio/5-205589-A-17.wav',
#  'sound/ESC-50-master/audio/4-161303-A-5.wav',
#  'sound/ESC-50-master/audio/4-212698-A-39.wav',
#  'sound/ESC-50-master/audio/2-73027-A-10.wav',
#  'sound/ESC-50-master/audio/2-79775-A-26.wav',
#  'sound/ESC-50-master/audio/5-178997-A-24.wav',
#  'sound/ESC-50-master/audio/5-234855-A-25.wav',
#  'sound/ESC-50-master/audio/1-91359-B-11.wav',
#  'sound/ESC-50-master/audio/3-71964-A-4.wav',
#  'sound/ESC-50-master/audio/2-52085-A-4.wav',
#  'sound/ESC-50-master/audio/4-191246-A-7.wav',
#  'sound/ESC-50-master/audio/3-208820-A-49.wav',
#  'sound/ESC-50-master/audio/2-102567-B-35.wav',
#  'sound/ESC-50-master/audio/5-195517-A-7.wav',
#  'sound/ESC-50-master/audio/1-73123-A-26.wav',
#  'sound/ESC-50-master/audio/3-155577-A-14.wav',
#  'sound/ESC-50-master/audio/3-104761-A-7.wav',
#  'sound/ESC-50-master/audio/4-161127-A-10.wav',
#  'sound/ESC-50-master/audio/5-193473-A-12.wav',
#  'sound/ESC-50-master/audio/4-107120-A-33.wav',
#  'sound/ESC-50-master/audio/2-25292-A-22.wav',
#  'sound/ESC-50-master/audio/1-63679-A-24.wav',
#  'sound/ESC-50-master/audio/5-160614-D-48.wav',
#  'sound/ESC-50-master/audio/1-39901-B-11.wav',
#  'sound/ESC-50-master/audio/4-181999-A-36.wav',
#  'sound/ESC-50-master/audio/1-36393-A-23.wav',
#  'sound/ESC-50-master/audio/2-196688-A-8.wav',
#  'sound/ESC-50-master/audio/2-7321-A-33.wav',
#  'sound/ESC-50-master/audio/1-18755-A-4.wav',
#  'sound/ESC-50-master/audio/4-149940-A-5.wav',
#  'sound/ESC-50-master/audio/1-30226-A-0.wav',
#  'sound/ESC-50-master/audio/2-102581-A-29.wav',
#  'sound/ESC-50-master/audio/1-96950-A-9.wav',
#  'sound/ESC-50-master/audio/4-167077-A-20.wav',
#  'sound/ESC-50-master/audio/5-202898-A-10.wav',
#  'sound/ESC-50-master/audio/3-112356-A-18.wav',
#  'sound/ESC-50-master/audio/3-62878-A-42.wav',
#  'sound/ESC-50-master/audio/1-76831-A-42.wav',
#  'sound/ESC-50-master/audio/5-214759-B-5.wav',
#  'sound/ESC-50-master/audio/2-77346-A-46.wav',
#  'sound/ESC-50-master/audio/3-118658-A-41.wav',
#  'sound/ESC-50-master/audio/5-219379-C-11.wav',
#  'sound/ESC-50-master/audio/2-83667-A-34.wav',
#  'sound/ESC-50-master/audio/5-213836-B-9.wav',
#  'sound/ESC-50-master/audio/2-59565-A-46.wav',
#  'sound/ESC-50-master/audio/2-98676-A-24.wav',
#  'sound/ESC-50-master/audio/3-103597-A-25.wav',
#  'sound/ESC-50-master/audio/2-112213-A-39.wav',
#  'sound/ESC-50-master/audio/5-198411-F-20.wav',
#  'sound/ESC-50-master/audio/4-155650-B-24.wav',
#  'sound/ESC-50-master/audio/2-70936-A-42.wav',
#  'sound/ESC-50-master/audio/4-198962-A-25.wav',
#  'sound/ESC-50-master/audio/2-139748-B-15.wav',
#  'sound/ESC-50-master/audio/4-181628-A-17.wav',
#  'sound/ESC-50-master/audio/3-144891-B-19.wav',
#  'sound/ESC-50-master/audio/3-118069-B-27.wav',
#  'sound/ESC-50-master/audio/3-117293-A-9.wav',
#  'sound/ESC-50-master/audio/2-109231-C-9.wav',
#  'sound/ESC-50-master/audio/1-68670-A-34.wav',
#  'sound/ESC-50-master/audio/4-130891-A-7.wav',
#  'sound/ESC-50-master/audio/3-157492-A-45.wav',
#  'sound/ESC-50-master/audio/5-192191-A-19.wav',
#  'sound/ESC-50-master/audio/1-69422-A-3.wav',
#  'sound/ESC-50-master/audio/4-154443-A-24.wav',
#  'sound/ESC-50-master/audio/5-244315-A-6.wav',
#  'sound/ESC-50-master/audio/5-117120-A-42.wav',
#  'sound/ESC-50-master/audio/3-117883-A-37.wav',
#  'sound/ESC-50-master/audio/5-160614-H-48.wav',
#  'sound/ESC-50-master/audio/2-117615-B-48.wav',
#  'sound/ESC-50-master/audio/3-144827-A-11.wav',
#  'sound/ESC-50-master/audio/2-98866-A-47.wav',
#  'sound/ESC-50-master/audio/3-170574-A-30.wav',
#  'sound/ESC-50-master/audio/4-156844-A-21.wav',
#  'sound/ESC-50-master/audio/3-127890-A-9.wav',
#  'sound/ESC-50-master/audio/1-34119-B-1.wav',
#  'sound/ESC-50-master/audio/5-215658-B-12.wav',
#  'sound/ESC-50-master/audio/1-30830-A-24.wav',
#  'sound/ESC-50-master/audio/1-60997-B-20.wav',
#  'sound/ESC-50-master/audio/5-233019-A-31.wav',
#  'sound/ESC-50-master/audio/5-200461-B-11.wav',
#  'sound/ESC-50-master/audio/3-144510-A-30.wav',
#  'sound/ESC-50-master/audio/5-207781-A-17.wav',
#  'sound/ESC-50-master/audio/3-143929-A-10.wav',
#  'sound/ESC-50-master/audio/4-172377-A-17.wav',
#  'sound/ESC-50-master/audio/2-122067-B-45.wav',
#  'sound/ESC-50-master/audio/3-144120-A-32.wav',
#  'sound/ESC-50-master/audio/1-28005-A-18.wav',
#  'sound/ESC-50-master/audio/3-123224-A-19.wav',
#  'sound/ESC-50-master/audio/3-171041-A-38.wav',
#  'sound/ESC-50-master/audio/3-119120-B-48.wav',
#  'sound/ESC-50-master/audio/1-196660-A-8.wav',
#  'sound/ESC-50-master/audio/2-85139-A-13.wav',
#  'sound/ESC-50-master/audio/1-30709-A-23.wav',
#  'sound/ESC-50-master/audio/4-99644-C-4.wav',
#  'sound/ESC-50-master/audio/1-45645-A-31.wav',
#  'sound/ESC-50-master/audio/1-18755-B-4.wav',
#  'sound/ESC-50-master/audio/4-165823-A-41.wav',
#  'sound/ESC-50-master/audio/4-102871-A-42.wav',
#  'sound/ESC-50-master/audio/4-80761-A-42.wav',
#  'sound/ESC-50-master/audio/5-243635-A-29.wav',
#  'sound/ESC-50-master/audio/2-108017-A-24.wav',
#  'sound/ESC-50-master/audio/5-223176-A-37.wav',
#  'sound/ESC-50-master/audio/1-35687-A-38.wav',
#  'sound/ESC-50-master/audio/5-189795-A-4.wav',
#  'sound/ESC-50-master/audio/5-261464-A-23.wav',
#  'sound/ESC-50-master/audio/5-219044-A-46.wav',
#  'sound/ESC-50-master/audio/5-238926-A-31.wav',
#  'sound/ESC-50-master/audio/3-144253-A-29.wav',
#  'sound/ESC-50-master/audio/2-122820-B-36.wav',
#  'sound/ESC-50-master/audio/2-109231-B-9.wav',
#  'sound/ESC-50-master/audio/1-40154-A-46.wav',
#  'sound/ESC-50-master/audio/1-61261-A-44.wav',
#  'sound/ESC-50-master/audio/2-51630-B-49.wav',
#  'sound/ESC-50-master/audio/3-147965-A-12.wav',
#  'sound/ESC-50-master/audio/5-194533-A-21.wav',
#  'sound/ESC-50-master/audio/5-212730-A-17.wav',
#  'sound/ESC-50-master/audio/5-223810-A-35.wav',
#  'sound/ESC-50-master/audio/4-107122-A-33.wav',
#  'sound/ESC-50-master/audio/4-179836-A-34.wav',
#  'sound/ESC-50-master/audio/1-61534-A-27.wav',
#  'sound/ESC-50-master/audio/2-107228-A-44.wav',
#  'sound/ESC-50-master/audio/1-87565-A-29.wav',
#  'sound/ESC-50-master/audio/5-262957-A-22.wav',
#  'sound/ESC-50-master/audio/3-166125-A-23.wav',
#  'sound/ESC-50-master/audio/2-106881-A-39.wav',
#  'sound/ESC-50-master/audio/4-250869-B-2.wav',
#  'sound/ESC-50-master/audio/1-61212-A-32.wav',
#  'sound/ESC-50-master/audio/4-189833-A-22.wav',
#  'sound/ESC-50-master/audio/3-140199-A-8.wav',
#  'sound/ESC-50-master/audio/3-132852-A-10.wav',
#  'sound/ESC-50-master/audio/1-85123-A-31.wav',
#  'sound/ESC-50-master/audio/5-216370-B-41.wav',
#  'sound/ESC-50-master/audio/2-173618-A-39.wav',
#  'sound/ESC-50-master/audio/4-125071-A-19.wav',
#  'sound/ESC-50-master/audio/4-167642-A-21.wav',
#  'sound/ESC-50-master/audio/5-194899-D-3.wav',
#  'sound/ESC-50-master/audio/5-182404-A-18.wav',
#  'sound/ESC-50-master/audio/4-59579-B-20.wav',
#  'sound/ESC-50-master/audio/1-80841-A-13.wav',
#  'sound/ESC-50-master/audio/5-234923-A-32.wav',
#  'sound/ESC-50-master/audio/4-182368-A-12.wav',
#  'sound/ESC-50-master/audio/4-163609-B-16.wav',
#  'sound/ESC-50-master/audio/2-209477-A-25.wav',
#  'sound/ESC-50-master/audio/5-233260-A-23.wav',
#  'sound/ESC-50-master/audio/3-134699-C-16.wav',
#  'sound/ESC-50-master/audio/5-201170-A-46.wav',
#  'sound/ESC-50-master/audio/5-216213-A-13.wav',
#  'sound/ESC-50-master/audio/1-57163-A-38.wav',
#  'sound/ESC-50-master/audio/1-53467-A-47.wav',
#  'sound/ESC-50-master/audio/2-67422-A-18.wav',
#  'sound/ESC-50-master/audio/2-118072-A-0.wav',
#  'sound/ESC-50-master/audio/5-203128-B-0.wav',
#  'sound/ESC-50-master/audio/1-94231-B-32.wav',
#  'sound/ESC-50-master/audio/4-160036-A-33.wav',
#  'sound/ESC-50-master/audio/1-51147-A-25.wav',
#  'sound/ESC-50-master/audio/1-24074-A-43.wav',
#  'sound/ESC-50-master/audio/5-150409-A-42.wav',
#  'sound/ESC-50-master/audio/2-99955-A-7.wav',
#  'sound/ESC-50-master/audio/3-166546-A-34.wav',
#  'sound/ESC-50-master/audio/1-196660-B-8.wav',
#  'sound/ESC-50-master/audio/5-211197-A-24.wav',
#  'sound/ESC-50-master/audio/5-197118-A-45.wav',
#  'sound/ESC-50-master/audio/2-37806-D-40.wav',
#  'sound/ESC-50-master/audio/1-67230-A-29.wav',
#  'sound/ESC-50-master/audio/4-157296-A-24.wav',
#  'sound/ESC-50-master/audio/4-111671-B-42.wav',
#  'sound/ESC-50-master/audio/2-146877-B-31.wav',
#  'sound/ESC-50-master/audio/5-200334-A-1.wav',
#  'sound/ESC-50-master/audio/5-249937-A-22.wav',
#  'sound/ESC-50-master/audio/2-125520-A-43.wav',
#  'sound/ESC-50-master/audio/5-204352-A-13.wav',
#  'sound/ESC-50-master/audio/4-132383-B-2.wav',
#  'sound/ESC-50-master/audio/4-216349-A-34.wav',
#  'sound/ESC-50-master/audio/2-152895-A-31.wav',
#  'sound/ESC-50-master/audio/5-256452-A-5.wav',
#  'sound/ESC-50-master/audio/5-243025-A-25.wav',
#  'sound/ESC-50-master/audio/1-51436-A-17.wav',
#  'sound/ESC-50-master/audio/5-188716-A-46.wav',
#  'sound/ESC-50-master/audio/4-183487-A-1.wav',
#  'sound/ESC-50-master/audio/3-143560-A-47.wav',
#  'sound/ESC-50-master/audio/4-192068-A-31.wav',
#  'sound/ESC-50-master/audio/3-172881-A-48.wav',
#  'sound/ESC-50-master/audio/2-117116-A-37.wav',
#  'sound/ESC-50-master/audio/2-32515-A-4.wav',
#  'sound/ESC-50-master/audio/2-104475-A-37.wav',
#  'sound/ESC-50-master/audio/5-233645-A-37.wav',
#  'sound/ESC-50-master/audio/1-50454-A-44.wav',
#  'sound/ESC-50-master/audio/3-144692-A-21.wav',
#  'sound/ESC-50-master/audio/4-212604-B-15.wav',
#  'sound/ESC-50-master/audio/2-126433-A-17.wav',
#  'sound/ESC-50-master/audio/3-71964-B-4.wav',
#  'sound/ESC-50-master/audio/3-253084-A-2.wav',
#  'sound/ESC-50-master/audio/1-21935-A-38.wav',
#  'sound/ESC-50-master/audio/1-39835-B-9.wav',
#  'sound/ESC-50-master/audio/3-154926-B-40.wav',
#  'sound/ESC-50-master/audio/2-109231-A-9.wav',
#  'sound/ESC-50-master/audio/4-172500-D-27.wav',
#  'sound/ESC-50-master/audio/3-96606-B-49.wav',
#  'sound/ESC-50-master/audio/4-99193-B-4.wav',
#  'sound/ESC-50-master/audio/4-210000-B-23.wav',
#  'sound/ESC-50-master/audio/3-172179-A-31.wav',
#  'sound/ESC-50-master/audio/3-70962-B-4.wav',
#  'sound/ESC-50-master/audio/5-188655-A-10.wav',
#  'sound/ESC-50-master/audio/4-189830-A-22.wav',
#  'sound/ESC-50-master/audio/1-20133-A-39.wav',
#  'sound/ESC-50-master/audio/5-250026-A-30.wav',
#  'sound/ESC-50-master/audio/5-156999-D-19.wav',
#  'sound/ESC-50-master/audio/2-50665-A-20.wav',
#  'sound/ESC-50-master/audio/4-164021-A-1.wav',
#  'sound/ESC-50-master/audio/1-30214-A-18.wav',
#  'sound/ESC-50-master/audio/2-50668-B-41.wav',
#  'sound/ESC-50-master/audio/2-77945-B-41.wav',
#  'sound/ESC-50-master/audio/1-71030-A-6.wav',
#  'sound/ESC-50-master/audio/4-125070-A-19.wav',
#  'sound/ESC-50-master/audio/4-178402-A-43.wav',
#  'sound/ESC-50-master/audio/4-159609-B-14.wav',
#  'sound/ESC-50-master/audio/4-213915-B-3.wav',
#  'sound/ESC-50-master/audio/1-18074-B-6.wav',
#  'sound/ESC-50-master/audio/4-172180-A-32.wav',
#  'sound/ESC-50-master/audio/4-121532-A-42.wav',
#  'sound/ESC-50-master/audio/2-25293-A-22.wav',
#  'sound/ESC-50-master/audio/3-171937-A-34.wav',
#  'sound/ESC-50-master/audio/2-122104-A-0.wav',
#  'sound/ESC-50-master/audio/2-85292-A-24.wav',
#  'sound/ESC-50-master/audio/4-181362-A-13.wav',
#  'sound/ESC-50-master/audio/3-170002-A-34.wav',
#  'sound/ESC-50-master/audio/3-147343-A-34.wav',
#  'sound/ESC-50-master/audio/4-174860-B-3.wav',
#  'sound/ESC-50-master/audio/3-155130-A-43.wav',
#  'sound/ESC-50-master/audio/2-134915-A-30.wav',
#  'sound/ESC-50-master/audio/2-102567-D-35.wav',
#  'sound/ESC-50-master/audio/4-111671-A-42.wav',
#  'sound/ESC-50-master/audio/1-51805-H-33.wav',
#  'sound/ESC-50-master/audio/2-93030-A-21.wav',
#  'sound/ESC-50-master/audio/1-40967-A-28.wav',
#  'sound/ESC-50-master/audio/3-104761-B-7.wav',
#  'sound/ESC-50-master/audio/1-58923-B-27.wav',
#  'sound/ESC-50-master/audio/3-149448-A-17.wav',
#  'sound/ESC-50-master/audio/1-49409-A-8.wav',
#  'sound/ESC-50-master/audio/5-211408-A-37.wav',
#  'sound/ESC-50-master/audio/2-102435-A-37.wav',
#  'sound/ESC-50-master/audio/1-19872-A-36.wav',
#  'sound/ESC-50-master/audio/1-18527-B-44.wav',
#  'sound/ESC-50-master/audio/3-161010-A-43.wav',
#  'sound/ESC-50-master/audio/4-146200-A-36.wav',
#  'sound/ESC-50-master/audio/4-184434-A-21.wav',
#  'sound/ESC-50-master/audio/3-142349-A-17.wav',
#  'sound/ESC-50-master/audio/3-171281-A-6.wav',
#  'sound/ESC-50-master/audio/2-130979-A-21.wav',
#  'sound/ESC-50-master/audio/4-183882-A-28.wav',
#  'sound/ESC-50-master/audio/5-216131-A-32.wav',
#  'sound/ESC-50-master/audio/5-213077-A-11.wav',
#  'sound/ESC-50-master/audio/4-119720-A-18.wav',
#  'sound/ESC-50-master/audio/1-23222-B-19.wav',
#  'sound/ESC-50-master/audio/2-119102-A-21.wav',
#  'sound/ESC-50-master/audio/3-144827-B-11.wav',
#  'sound/ESC-50-master/audio/4-161099-A-47.wav',
#  'sound/ESC-50-master/audio/3-152007-B-20.wav',
#  'sound/ESC-50-master/audio/4-188191-A-29.wav',
#  'sound/ESC-50-master/audio/5-250026-B-30.wav',
#  'sound/ESC-50-master/audio/3-152007-C-20.wav',
#  'sound/ESC-50-master/audio/4-144083-C-16.wav',
#  'sound/ESC-50-master/audio/2-60794-A-26.wav',
#  'sound/ESC-50-master/audio/4-163609-A-16.wav',
#  'sound/ESC-50-master/audio/3-157149-A-10.wav',
#  'sound/ESC-50-master/audio/5-242932-A-26.wav',
#  'sound/ESC-50-master/audio/5-252248-A-34.wav',
#  'sound/ESC-50-master/audio/3-144128-B-23.wav',
#  'sound/ESC-50-master/audio/4-107117-A-33.wav',
#  'sound/ESC-50-master/audio/4-169127-A-41.wav',
#  'sound/ESC-50-master/audio/5-195518-A-7.wav',
#  'sound/ESC-50-master/audio/3-148330-A-21.wav',
#  'sound/ESC-50-master/audio/1-23706-A-49.wav',
#  'sound/ESC-50-master/audio/5-235893-A-28.wav',
#  'sound/ESC-50-master/audio/5-170338-A-41.wav',
#  'sound/ESC-50-master/audio/4-250869-C-2.wav',
#  'sound/ESC-50-master/audio/4-164206-A-10.wav',
#  'sound/ESC-50-master/audio/5-191497-A-33.wav',
#  'sound/ESC-50-master/audio/3-163607-B-13.wav',
#  'sound/ESC-50-master/audio/5-180156-B-43.wav',
#  'sound/ESC-50-master/audio/5-177957-D-40.wav',
#  'sound/ESC-50-master/audio/3-166422-A-11.wav',
#  'sound/ESC-50-master/audio/3-152020-A-36.wav',
#  'sound/ESC-50-master/audio/1-118206-A-31.wav',
#  'sound/ESC-50-master/audio/4-165791-B-45.wav',
#  'sound/ESC-50-master/audio/1-101404-A-34.wav',
#  'sound/ESC-50-master/audio/4-204612-A-31.wav',
#  'sound/ESC-50-master/audio/2-39945-A-19.wav',
#  'sound/ESC-50-master/audio/1-79711-A-32.wav',
#  'sound/ESC-50-master/audio/4-184575-A-0.wav',
#  'sound/ESC-50-master/audio/3-51731-A-42.wav',
#  'sound/ESC-50-master/audio/5-219342-A-38.wav',
#  'sound/ESC-50-master/audio/1-155858-D-25.wav',
#  'sound/ESC-50-master/audio/1-24524-A-19.wav',
#  'sound/ESC-50-master/audio/2-141681-A-36.wav',
#  'sound/ESC-50-master/audio/5-200461-A-11.wav',
#  'sound/ESC-50-master/audio/5-202220-A-21.wav',
#  'sound/ESC-50-master/audio/2-91912-B-33.wav',
#  'sound/ESC-50-master/audio/1-155858-C-25.wav',
#  'sound/ESC-50-master/audio/3-108160-A-23.wav',
#  'sound/ESC-50-master/audio/5-171118-A-26.wav',
#  'sound/ESC-50-master/audio/2-122067-A-45.wav',
#  'sound/ESC-50-master/audio/3-118657-B-41.wav',
#  'sound/ESC-50-master/audio/3-127874-A-17.wav',
#  'sound/ESC-50-master/audio/5-220026-A-21.wav',
#  'sound/ESC-50-master/audio/5-234879-A-1.wav',
#  'sound/ESC-50-master/audio/3-164630-A-11.wav',
#  'sound/ESC-50-master/audio/5-156026-B-4.wav',
#  'sound/ESC-50-master/audio/4-175845-A-43.wav',
#  'sound/ESC-50-master/audio/2-132157-B-11.wav',
#  'sound/ESC-50-master/audio/5-156999-A-19.wav',
#  'sound/ESC-50-master/audio/1-39835-A-9.wav',
#  'sound/ESC-50-master/audio/4-204123-A-39.wav',
#  'sound/ESC-50-master/audio/2-72547-B-14.wav',
#  'sound/ESC-50-master/audio/4-187284-A-30.wav',
#  'sound/ESC-50-master/audio/2-109759-A-26.wav',
#  'sound/ESC-50-master/audio/3-197408-A-8.wav',
#  'sound/ESC-50-master/audio/4-207124-A-0.wav',
#  'sound/ESC-50-master/audio/1-46274-A-18.wav',
#  'sound/ESC-50-master/audio/5-219379-A-11.wav',
#  'sound/ESC-50-master/audio/2-120218-A-30.wav',
#  'sound/ESC-50-master/audio/3-164216-C-6.wav',
#  'sound/ESC-50-master/audio/5-234263-A-25.wav',
#  'sound/ESC-50-master/audio/2-30322-B-12.wav',
#  'sound/ESC-50-master/audio/1-96890-A-37.wav',
#  'sound/ESC-50-master/audio/3-141240-B-44.wav',
#  'sound/ESC-50-master/audio/3-146186-A-44.wav',
#  'sound/ESC-50-master/audio/5-141683-A-35.wav',
#  'sound/ESC-50-master/audio/2-137162-A-11.wav',
#  'sound/ESC-50-master/audio/1-211527-C-20.wav',
#  'sound/ESC-50-master/audio/1-97392-A-0.wav',
#  'sound/ESC-50-master/audio/3-152020-C-36.wav',
#  'sound/ESC-50-master/audio/4-191015-A-43.wav',
#  'sound/ESC-50-master/audio/3-145719-A-17.wav',
#  'sound/ESC-50-master/audio/3-167096-A-31.wav',
#  'sound/ESC-50-master/audio/2-144137-A-43.wav',
#  'sound/ESC-50-master/audio/3-149042-A-24.wav',
#  'sound/ESC-50-master/audio/1-29532-A-16.wav',
#  'sound/ESC-50-master/audio/3-129338-A-13.wav',
#  'sound/ESC-50-master/audio/3-151557-A-28.wav',
#  'sound/ESC-50-master/audio/4-204684-A-37.wav',
#  'sound/ESC-50-master/audio/1-57316-A-13.wav',
#  'sound/ESC-50-master/audio/2-96063-A-37.wav',
#  'sound/ESC-50-master/audio/3-148932-A-34.wav',
#  'sound/ESC-50-master/audio/1-27166-A-35.wav',
#  'sound/ESC-50-master/audio/5-180229-A-27.wav',
#  'sound/ESC-50-master/audio/1-115545-A-48.wav',
#  'sound/ESC-50-master/audio/3-107123-A-26.wav',
#  'sound/ESC-50-master/audio/5-177034-A-18.wav',
#  'sound/ESC-50-master/audio/5-222524-A-41.wav',
#  'sound/ESC-50-master/audio/4-164661-A-12.wav',
#  'sound/ESC-50-master/audio/3-155642-B-11.wav',
#  'sound/ESC-50-master/audio/1-56907-A-46.wav',
#  'sound/ESC-50-master/audio/2-209476-A-25.wav',
#  'sound/ESC-50-master/audio/5-218980-A-30.wav',
#  'sound/ESC-50-master/audio/4-210309-A-31.wav',
#  'sound/ESC-50-master/audio/5-160614-G-48.wav',
#  'sound/ESC-50-master/audio/3-156393-A-35.wav',
#  'sound/ESC-50-master/audio/2-42101-A-43.wav',
#  'sound/ESC-50-master/audio/1-121951-A-8.wav',
#  'sound/ESC-50-master/audio/2-182508-B-8.wav',
#  'sound/ESC-50-master/audio/4-234644-A-2.wav',
#  'sound/ESC-50-master/audio/3-128512-A-47.wav',
#  'sound/ESC-50-master/audio/4-161105-A-47.wav',
#  'sound/ESC-50-master/audio/2-100648-A-43.wav',
#  'sound/ESC-50-master/audio/2-105270-A-47.wav',
#  'sound/ESC-50-master/audio/5-243773-A-44.wav',
#  'sound/ESC-50-master/audio/2-83934-B-5.wav',
#  'sound/ESC-50-master/audio/3-118194-A-33.wav',
#  'sound/ESC-50-master/audio/4-185575-A-20.wav',
#  'sound/ESC-50-master/audio/2-65750-A-1.wav',
#  'sound/ESC-50-master/audio/5-204741-A-46.wav',
#  'sound/ESC-50-master/audio/2-106486-A-44.wav',
#  'sound/ESC-50-master/audio/4-141365-A-18.wav',
#  'sound/ESC-50-master/audio/5-242491-A-14.wav',
#  'sound/ESC-50-master/audio/4-99644-B-4.wav',
#  'sound/ESC-50-master/audio/3-51731-B-42.wav',
#  'sound/ESC-50-master/audio/2-173607-A-39.wav',
#  'sound/ESC-50-master/audio/5-220027-A-21.wav',
#  'sound/ESC-50-master/audio/2-109371-D-16.wav',
#  'sound/ESC-50-master/audio/4-154405-A-27.wav',
#  'sound/ESC-50-master/audio/1-32579-A-29.wav',
#  'sound/ESC-50-master/audio/5-235956-A-47.wav',
#  'sound/ESC-50-master/audio/2-130245-A-34.wav',
#  'sound/ESC-50-master/audio/3-155556-A-31.wav',
#  'sound/ESC-50-master/audio/4-119647-D-48.wav',
#  'sound/ESC-50-master/audio/3-197435-B-22.wav',
#  'sound/ESC-50-master/audio/5-207836-D-29.wav',
#  'sound/ESC-50-master/audio/2-83270-A-13.wav',
#  'sound/ESC-50-master/audio/3-101381-A-33.wav',
#  'sound/ESC-50-master/audio/5-221568-A-22.wav',
#  'sound/ESC-50-master/audio/4-188703-B-8.wav',
#  'sound/ESC-50-master/audio/4-192236-A-0.wav',
#  'sound/ESC-50-master/audio/4-133674-A-26.wav',
#  'sound/ESC-50-master/audio/2-81970-A-7.wav',
#  'sound/ESC-50-master/audio/1-24076-A-43.wav',
#  'sound/ESC-50-master/audio/3-154378-A-30.wav',
#  'sound/ESC-50-master/audio/3-142593-A-38.wav',
#  'sound/ESC-50-master/audio/3-157187-A-12.wav',
#  'sound/ESC-50-master/audio/4-165933-A-45.wav',
#  'sound/ESC-50-master/audio/1-47819-C-5.wav',
#  'sound/ESC-50-master/audio/3-146873-A-24.wav',
#  'sound/ESC-50-master/audio/2-61311-A-12.wav',
#  'sound/ESC-50-master/audio/1-53501-A-32.wav',
#  'sound/ESC-50-master/audio/4-172500-B-27.wav',
#  'sound/ESC-50-master/audio/4-175855-A-43.wav',
#  'sound/ESC-50-master/audio/4-159609-A-14.wav',
#  'sound/ESC-50-master/audio/5-263831-A-6.wav',
#  'sound/ESC-50-master/audio/1-60997-A-20.wav',
#  'sound/ESC-50-master/audio/2-28314-A-12.wav',
#  'sound/ESC-50-master/audio/1-17742-A-12.wav',
#  'sound/ESC-50-master/audio/4-182369-A-12.wav',
#  'sound/ESC-50-master/audio/5-219379-B-11.wav',
#  'sound/ESC-50-master/audio/3-154439-A-17.wav',
#  'sound/ESC-50-master/audio/1-7456-A-13.wav',
#  'sound/ESC-50-master/audio/1-18757-A-4.wav',
#  'sound/ESC-50-master/audio/5-177957-B-40.wav',
#  'sound/ESC-50-master/audio/2-91912-A-33.wav',
#  'sound/ESC-50-master/audio/3-124925-A-9.wav',
#  'sound/ESC-50-master/audio/4-182839-A-17.wav',
#  'sound/ESC-50-master/audio/1-88409-B-45.wav',
#  'sound/ESC-50-master/audio/3-103051-A-19.wav',
#  'sound/ESC-50-master/audio/1-19872-B-36.wav',
#  'sound/ESC-50-master/audio/5-213836-D-9.wav',
#  'sound/ESC-50-master/audio/5-221878-A-34.wav',
#  'sound/ESC-50-master/audio/4-181035-A-38.wav',
#  'sound/ESC-50-master/audio/3-107219-A-1.wav',
#  'sound/ESC-50-master/audio/5-209992-A-44.wav',
#  'sound/ESC-50-master/audio/4-205738-A-22.wav',
#  'sound/ESC-50-master/audio/3-151081-B-20.wav',
#  'sound/ESC-50-master/audio/4-117630-A-25.wav',
#  'sound/ESC-50-master/audio/5-215449-A-47.wav',
#  'sound/ESC-50-master/audio/4-253649-A-6.wav',
#  'sound/ESC-50-master/audio/2-94230-A-27.wav',
#  'sound/ESC-50-master/audio/4-218199-F-35.wav',
#  'sound/ESC-50-master/audio/3-152912-A-26.wav',
#  'sound/ESC-50-master/audio/1-260640-A-2.wav',
#  'sound/ESC-50-master/audio/3-136451-A-45.wav',
#  'sound/ESC-50-master/audio/4-218199-E-35.wav',
#  'sound/ESC-50-master/audio/4-186962-A-44.wav',
#  'sound/ESC-50-master/audio/5-219242-B-37.wav',
#  'sound/ESC-50-master/audio/2-124662-A-11.wav',
#  'sound/ESC-50-master/audio/4-163264-A-10.wav',
#  'sound/ESC-50-master/audio/2-109371-A-16.wav',
#  'sound/ESC-50-master/audio/2-141682-B-36.wav',
#  'sound/ESC-50-master/audio/5-201194-A-38.wav',
#  'sound/ESC-50-master/audio/1-172649-D-40.wav',
#  'sound/ESC-50-master/audio/4-152995-A-24.wav',
#  'sound/ESC-50-master/audio/4-167077-C-20.wav',
#  'sound/ESC-50-master/audio/5-209719-A-24.wav',
#  'sound/ESC-50-master/audio/4-181708-A-32.wav',
#  'sound/ESC-50-master/audio/2-32515-D-4.wav',
#  'sound/ESC-50-master/audio/3-159348-A-36.wav',
#  'sound/ESC-50-master/audio/5-103421-A-2.wav',
#  'sound/ESC-50-master/audio/5-251962-A-47.wav',
#  'sound/ESC-50-master/audio/1-208757-D-2.wav',
#  'sound/ESC-50-master/audio/3-128512-B-47.wav',
#  'sound/ESC-50-master/audio/1-29680-A-21.wav',
#  'sound/ESC-50-master/audio/2-54962-A-23.wav',
#  'sound/ESC-50-master/audio/3-172922-A-48.wav',
#  'sound/ESC-50-master/audio/3-103051-C-19.wav',
#  'sound/ESC-50-master/audio/5-212181-A-38.wav',
#  'sound/ESC-50-master/audio/2-76408-C-22.wav',
#  'sound/ESC-50-master/audio/5-257839-A-14.wav',
#  'sound/ESC-50-master/audio/1-181071-A-40.wav',
#  'sound/ESC-50-master/audio/5-203128-A-0.wav',
#  'sound/ESC-50-master/audio/1-31251-A-6.wav',
#  'sound/ESC-50-master/audio/4-234879-A-6.wav',
#  'sound/ESC-50-master/audio/1-100032-A-0.wav',
#  'sound/ESC-50-master/audio/3-134802-A-13.wav',
#  'sound/ESC-50-master/audio/4-99193-A-4.wav',
#  'sound/ESC-50-master/audio/5-259640-A-29.wav',
#  'sound/ESC-50-master/audio/5-182010-A-36.wav',
#  'sound/ESC-50-master/audio/3-108451-A-17.wav',
#  'sound/ESC-50-master/audio/2-96904-A-27.wav',
#  'sound/ESC-50-master/audio/1-44831-A-1.wav',
#  'sound/ESC-50-master/audio/2-135649-B-45.wav',
#  'sound/ESC-50-master/audio/3-154758-A-44.wav',
#  'sound/ESC-50-master/audio/4-154793-A-4.wav',
#  'sound/ESC-50-master/audio/3-169907-A-29.wav',
#  'sound/ESC-50-master/audio/4-204777-B-39.wav',
#  'sound/ESC-50-master/audio/4-181955-B-3.wav',
#  'sound/ESC-50-master/audio/1-18527-A-44.wav',
#  'sound/ESC-50-master/audio/5-187201-A-4.wav',
#  'sound/ESC-50-master/audio/5-217186-A-16.wav',
#  'sound/ESC-50-master/audio/5-212054-A-36.wav',
#  'sound/ESC-50-master/audio/2-77945-A-41.wav',
#  'sound/ESC-50-master/audio/2-117615-D-48.wav',
#  'sound/ESC-50-master/audio/2-108766-A-9.wav',
#  'sound/ESC-50-master/audio/1-105224-A-22.wav',
#  'sound/ESC-50-master/audio/4-90014-A-42.wav',
#  'sound/ESC-50-master/audio/4-188003-A-34.wav',
#  'sound/ESC-50-master/audio/5-242932-B-26.wav',
#  'sound/ESC-50-master/audio/4-135439-A-18.wav',
#  'sound/ESC-50-master/audio/4-204618-A-11.wav',
#  'sound/ESC-50-master/audio/2-60795-A-26.wav',
#  'sound/ESC-50-master/audio/3-121348-A-9.wav',
#  'sound/ESC-50-master/audio/3-166125-B-23.wav',
#  'sound/ESC-50-master/audio/5-244327-A-34.wav',
#  'sound/ESC-50-master/audio/1-36397-A-23.wav',
#  'sound/ESC-50-master/audio/1-22882-A-44.wav',
#  'sound/ESC-50-master/audio/1-19898-A-41.wav',
#  'sound/ESC-50-master/audio/1-23996-A-35.wav',
#  'sound/ESC-50-master/audio/5-221529-A-39.wav',
#  'sound/ESC-50-master/audio/1-88409-A-45.wav',
#  'sound/ESC-50-master/audio/2-39441-A-19.wav',
#  'sound/ESC-50-master/audio/5-251489-A-24.wav',
#  'sound/ESC-50-master/audio/2-81731-A-10.wav',
#  'sound/ESC-50-master/audio/3-103598-A-25.wav',
#  'sound/ESC-50-master/audio/1-67152-A-17.wav',
#  'sound/ESC-50-master/audio/3-170383-A-38.wav',
#  'sound/ESC-50-master/audio/1-20545-A-28.wav',
#  'sound/ESC-50-master/audio/3-143562-A-47.wav',
#  'sound/ESC-50-master/audio/1-85362-A-0.wav',
#  'sound/ESC-50-master/audio/5-151085-A-20.wav',
#  'sound/ESC-50-master/audio/3-164595-A-15.wav',
#  'sound/ESC-50-master/audio/2-18766-A-12.wav',
#  'sound/ESC-50-master/audio/1-211527-A-20.wav',
#  'sound/ESC-50-master/audio/1-101296-A-19.wav',
#  'sound/ESC-50-master/audio/1-17808-A-12.wav',
#  'sound/ESC-50-master/audio/2-60180-A-49.wav',
#  'sound/ESC-50-master/audio/2-59566-A-46.wav',
#  'sound/ESC-50-master/audio/5-244315-C-6.wav',
#  'sound/ESC-50-master/audio/5-208810-A-11.wav',
#  'sound/ESC-50-master/audio/2-83688-A-34.wav',
#  'sound/ESC-50-master/audio/5-237499-A-4.wav',
#  'sound/ESC-50-master/audio/1-26176-A-43.wav',
#  'sound/ESC-50-master/audio/1-19111-A-24.wav',
#  'sound/ESC-50-master/audio/5-219318-A-31.wav',
#  'sound/ESC-50-master/audio/1-15689-A-4.wav',
#  'sound/ESC-50-master/audio/3-126358-B-3.wav',
#  'sound/ESC-50-master/audio/1-37226-A-29.wav',
#  'sound/ESC-50-master/audio/4-194711-A-38.wav',
#  'sound/ESC-50-master/audio/4-163697-A-13.wav',
#  'sound/ESC-50-master/audio/4-99644-D-4.wav',
#  'sound/ESC-50-master/audio/2-158746-C-2.wav',
#  'sound/ESC-50-master/audio/4-108352-A-33.wav',
#  'sound/ESC-50-master/audio/2-153388-A-31.wav',
#  'sound/ESC-50-master/audio/3-180147-A-30.wav',
#  ...]

# %% [markdown]
# # Define a function to covert the image based on calculate log scaled mel-spectrograms and their corresponding deltas from a sound clip.

# %% [markdown]
# Regarding fixed size input, we will divide each sound clip into segments of 60x41 (60 rows and 41 columns). The mel-spec and their deltas will become two channels, which we will be fed into CNN

# %%
# !pip install librosa
import librosa

# %%
def windows(data, window_size):
    start = 0
    while start < len(data):
        yield int(start), int(start + window_size)
        start += (window_size / 2)

def extract_features(bands = 60, frames = 41):
    window_size = 512 * (frames - 1)
    log_specgrams = []
    labels = []
    for fn in tqdm(glob('sound/ESC-50-master/audio/*')):
        sound_clip,s = librosa.load(fn) # 5sec
        sound_clip   = np.concatenate((sound_clip,sound_clip),axis=None) # make it 10s
        label = fn.split("/")[-1].split("-")[-1].split(".")[0]
        for (start,end) in windows(sound_clip,window_size):
            if(len(sound_clip[start:end]) == window_size):
                signal = sound_clip[start:end]
                melspec = librosa.feature.melspectrogram(signal, n_mels = bands)
                logspec = librosa.core.amplitude_to_db(melspec)
                logspec = logspec.T.flatten()[:, np.newaxis].T
                log_specgrams.append(logspec)
                labels.append(label)
            
    log_specgrams = np.asarray(log_specgrams).reshape(len(log_specgrams),bands,frames,1)
    features = np.concatenate((log_specgrams, np.zeros(np.shape(log_specgrams))), axis = 3)
    for i in range(len(features)):
        features[i, :, :, 1] = librosa.feature.delta(features[i, :, :, 0])
    
    return np.array(features), np.array(labels,dtype = np.int)

# %%
features,labels = extract_features()
# Out:
# 100%|██████████| 2000/2000 [09:37<00:00,  3.46it/s]
# /opt/conda/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
# label category names
df = pd.read_csv(glob('sound/ESC-50-master/meta/esc50.csv')[0])
df = df[['target','category']]
df = df.drop_duplicates().reset_index(drop=True)
df = df.sort_values(by=['target']).reset_index(drop=True)
df.head()
# Out:
#    target category
# 0       0      dog
# 1       1  rooster
# 2       2      pig
# 3       3      cow
# 4       4     frog

# %%
my_dict = {}
for i in range(len(df)):
    my_dict[df['target'][i]] = df['category'][i]
my_dict
# Out:
# {0: 'dog',
#  1: 'rooster',
#  2: 'pig',
#  3: 'cow',
#  4: 'frog',
#  5: 'cat',
#  6: 'hen',
#  7: 'insects',
#  8: 'sheep',
#  9: 'crow',
#  10: 'rain',
#  11: 'sea_waves',
#  12: 'crackling_fire',
#  13: 'crickets',
#  14: 'chirping_birds',
#  15: 'water_drops',
#  16: 'wind',
#  17: 'pouring_water',
#  18: 'toilet_flush',
#  19: 'thunderstorm',
#  20: 'crying_baby',
#  21: 'sneezing',
#  22: 'clapping',
#  23: 'breathing',
#  24: 'coughing',
#  25: 'footsteps',
#  26: 'laughing',
#  27: 'brushing_teeth',
#  28: 'snoring',
#  29: 'drinking_sipping',
#  30: 'door_wood_knock',
#  31: 'mouse_click',
#  32: 'keyboard_typing',
#  33: 'door_wood_creaks',
#  34: 'can_opening',
#  35: 'washing_machine',
#  36: 'vacuum_cleaner',
#  37: 'clock_alarm',
#  38: 'clock_tick',
#  39: 'glass_breaking',
#  40: 'helicopter',
#  41: 'chainsaw',
#  42: 'siren',
#  43: 'car_horn',
#  44: 'engine',
#  45: 'train',
#  46: 'church_bells',
#  47: 'airplane',
#  48: 'fireworks',
#  49: 'hand_saw'}

# %%
seed = 4
rng = np.random.RandomState(seed)
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
onehot_labels = to_categorical(labels,num_classes=50)

# %%
# Create train test Dataset

rnd_indices = np.random.rand(len(labels)) < 0.70

X_train = features[rnd_indices]
y_train = onehot_labels[rnd_indices]
X_test  = features[~rnd_indices]
y_test  = onehot_labels[~rnd_indices]

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((27998, 60, 41, 2), (27998, 50), (12002, 60, 41, 2), (12002, 50))

# %% [markdown]
# # CNN Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten,InputLayer
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras.optimizers import SGD, Adam, RMSprop
from keras.constraints import maxnorm
from keras.callbacks import ModelCheckpoint
from keras.initializers import normal, VarianceScaling
from keras import initializers
from keras.layers import BatchNormalization
### initializer of weights
# initializer = normal(mean=0, stddev=0.01, seed=13)
initializer = VarianceScaling(scale=1.0, mode='fan_in', distribution='normal', seed=None)

# %%
def basemodel():
    model = Sequential()
    model.add(Conv2D(32, (2, 2), input_shape=(60,41,2), activation='relu', padding='same', kernel_initializer=initializers.RandomUniform(minval=-0.05, maxval=0.05, seed=None), bias_initializer='ones'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Conv2D(32, (2, 2), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (2, 2), activation='relu', padding='same'))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (2, 2), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (2, 2), activation='relu', padding='same'))
    model.add(Dropout(0.2))
    model.add(Conv2D(128, (2, 2), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(1024, activation='relu', kernel_constraint=maxnorm(3)))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
    model.add(Dropout(0.2))
    model.add(Dense(50, activation='softmax'))
    
    # Compile model
    epochs, lrate = 25, 0.01
    decay = lrate/epochs
    
#     sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
    adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay, amsgrad=False)
#     rms = RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=decay)
    model.compile(loss='categorical_crossentropy', optimizer = adam, metrics=['accuracy'])
    return model

# %%
if not os.path.exists('model'):
    os.makedirs('model')
    
filepath="model/weights_0.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model = basemodel()
# model.load_weights('./model/weights_0.best.hdf5')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_160 (Conv2D)          (None, 60, 41, 32)        288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 41, 32)        128
# _________________________________________________________________
# dropout_125 (Dropout)        (None, 60, 41, 32)        0
# _________________________________________________________________
# conv2d_161 (Conv2D)          (None, 60, 41, 32)        4128
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 30, 20, 32)        0
# _________________________________________________________________
# conv2d_162 (Conv2D)          (None, 30, 20, 64)        8256
# _________________________________________________________________
# dropout_126 (Dropout)        (None, 30, 20, 64)        0
# _________________________________________________________________
# conv2d_163 (Conv2D)          (None, 30, 20, 64)        16448
# _________________________________________________________________
# max_pooling2d_76 (MaxPooling (None, 15, 10, 64)        0
# _________________________________________________________________
# conv2d_164 (Conv2D)          (None, 15, 10, 128)       32896
# _________________________________________________________________
# dropout_127 (Dropout)        (None, 15, 10, 128)       0
# _________________________________________________________________
# conv2d_165 (Conv2D)          (None, 15, 10, 128)       65664
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 7, 5, 128)         0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 4480)              0
# _________________________________________________________________
# dropout_128 (Dropout)        (None, 4480)              0
# _________________________________________________________________
# dense_64 (Dense)             (None, 1024)              4588544
# _________________________________________________________________
# dropout_129 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_65 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_66 (Dense)             (None, 50)                25650
# =================================================================
# Total params: 5,266,802
# Trainable params: 5,266,738
# Non-trainable params: 64
# _________________________________________________________________
# None

# %% [markdown]
# # Training with Data Augmentation

# %% [markdown]
# One of the major reasons for overfitting is that we don’t have enough data to train our network. Apart from regularization, another very effective way to counter Overfitting is Data Augmentation. It is the process of artificially creating more images from the images you already have by changing the size, orientation etc of the image. It can be a tedious task but fortunately, this can be done in Keras using the ImageDataGenerator instance.

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
              width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
              height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
              horizontal_flip=True,  # randomly flip images
              vertical_flip=False  # randomly flip images
          )

# %%
# init the batch size and epochs

'''
Note: Due to Memory Error like Buffered data was truncated after reaching the output size limit. What i did is that Save the model in for example 60th epoch and close current program and run new program and restore saved model and train model from 61 epoch to 120 epoch and 
save that and close program and repeat this work for your interested epoch For this [100,50] three times repeat 

'''
batch_size = 50
epochs = 100

# %%
# fit the model
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                              steps_per_epoch=int(np.ceil(X_train.shape[0] / float(batch_size))),
                              epochs=epochs,
                              validation_data=(X_test, y_test),
                              verbose=1,callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_preprocessing/image/numpy_array_iterator.py:127: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (27998, 60, 41, 2) (2 channels).
#   str(self.x.shape[channels_axis]) + ' channels).')
# Epoch 1/100
# 560/560 [==============================] - 22s 40ms/step - loss: 3.4876 - acc: 0.0757 - val_loss: 3.2880 - val_acc: 0.0992
#
# Epoch 00001: val_acc improved from -inf to 0.09915, saving model to model/weights_0.best.hdf5
# Epoch 2/100
# 560/560 [==============================] - 17s 31ms/step - loss: 2.9663 - acc: 0.1729 - val_loss: 2.8232 - val_acc: 0.2183
#
# Epoch 00002: val_acc improved from 0.09915 to 0.21830, saving model to model/weights_0.best.hdf5
# Epoch 3/100
# 560/560 [==============================] - 17s 31ms/step - loss: 2.5822 - acc: 0.2573 - val_loss: 2.3750 - val_acc: 0.3091
#
# Epoch 00003: val_acc improved from 0.21830 to 0.30912, saving model to model/weights_0.best.hdf5
# Epoch 4/100
# 560/560 [==============================] - 17s 31ms/step - loss: 2.3361 - acc: 0.3192 - val_loss: 2.1864 - val_acc: 0.3586
#
# Epoch 00004: val_acc improved from 0.30912 to 0.35861, saving model to model/weights_0.best.hdf5
# Epoch 5/100
# 560/560 [==============================] - 17s 31ms/step - loss: 2.1656 - acc: 0.3649 - val_loss: 2.0792 - val_acc: 0.3932
#
# Epoch 00005: val_acc improved from 0.35861 to 0.39318, saving model to model/weights_0.best.hdf5
# Epoch 6/100
# 560/560 [==============================] - 17s 31ms/step - loss: 2.0364 - acc: 0.3981 - val_loss: 1.9875 - val_acc: 0.4253
#
# Epoch 00006: val_acc improved from 0.39318 to 0.42526, saving model to model/weights_0.best.hdf5
# Epoch 7/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.9325 - acc: 0.4226 - val_loss: 1.8993 - val_acc: 0.4365
#
# Epoch 00007: val_acc improved from 0.42526 to 0.43651, saving model to model/weights_0.best.hdf5
# Epoch 8/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.8520 - acc: 0.4481 - val_loss: 1.8543 - val_acc: 0.4495
#
# Epoch 00008: val_acc improved from 0.43651 to 0.44951, saving model to model/weights_0.best.hdf5
# Epoch 9/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.7640 - acc: 0.4693 - val_loss: 1.7291 - val_acc: 0.4858
#
# Epoch 00009: val_acc improved from 0.44951 to 0.48575, saving model to model/weights_0.best.hdf5
# Epoch 10/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.6975 - acc: 0.4859 - val_loss: 1.6819 - val_acc: 0.5010
#
# Epoch 00010: val_acc improved from 0.48575 to 0.50100, saving model to model/weights_0.best.hdf5
# Epoch 11/100
# 560/560 [==============================] - 18s 31ms/step - loss: 1.6263 - acc: 0.5046 - val_loss: 1.6827 - val_acc: 0.4971
#
# Epoch 00011: val_acc did not improve from 0.50100
# Epoch 12/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.5683 - acc: 0.5238 - val_loss: 1.5552 - val_acc: 0.5282
#
# Epoch 00012: val_acc improved from 0.50100 to 0.52816, saving model to model/weights_0.best.hdf5
# Epoch 13/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.5169 - acc: 0.5390 - val_loss: 1.5479 - val_acc: 0.5438
#
# Epoch 00013: val_acc improved from 0.52816 to 0.54383, saving model to model/weights_0.best.hdf5
# Epoch 14/100
# 560/560 [==============================] - 18s 31ms/step - loss: 1.4643 - acc: 0.5495 - val_loss: 1.4868 - val_acc: 0.5537
#
# Epoch 00014: val_acc improved from 0.54383 to 0.55366, saving model to model/weights_0.best.hdf5
# Epoch 15/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.4324 - acc: 0.5664 - val_loss: 1.4686 - val_acc: 0.5612
#
# Epoch 00015: val_acc improved from 0.55366 to 0.56124, saving model to model/weights_0.best.hdf5
# Epoch 16/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.3852 - acc: 0.5753 - val_loss: 1.5158 - val_acc: 0.5513
#
# Epoch 00016: val_acc did not improve from 0.56124
# Epoch 17/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.3551 - acc: 0.5810 - val_loss: 1.4162 - val_acc: 0.5772
#
# Epoch 00017: val_acc improved from 0.56124 to 0.57715, saving model to model/weights_0.best.hdf5
# Epoch 18/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.3103 - acc: 0.5975 - val_loss: 1.4306 - val_acc: 0.5675
#
# Epoch 00018: val_acc did not improve from 0.57715
# Epoch 19/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.2837 - acc: 0.6034 - val_loss: 1.3342 - val_acc: 0.5993
#
# Epoch 00019: val_acc improved from 0.57715 to 0.59932, saving model to model/weights_0.best.hdf5
# Epoch 20/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.2574 - acc: 0.6114 - val_loss: 1.3495 - val_acc: 0.5963
#
# Epoch 00020: val_acc did not improve from 0.59932
# Epoch 21/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.2294 - acc: 0.6197 - val_loss: 1.3953 - val_acc: 0.5810
#
# Epoch 00021: val_acc did not improve from 0.59932
# Epoch 22/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.2061 - acc: 0.6279 - val_loss: 1.2878 - val_acc: 0.6148
#
# Epoch 00022: val_acc improved from 0.59932 to 0.61481, saving model to model/weights_0.best.hdf5
# Epoch 23/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.1704 - acc: 0.6380 - val_loss: 1.3325 - val_acc: 0.5997
#
# Epoch 00023: val_acc did not improve from 0.61481
# Epoch 24/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.1594 - acc: 0.6387 - val_loss: 1.3936 - val_acc: 0.5874
#
# Epoch 00024: val_acc did not improve from 0.61481
# Epoch 25/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.1325 - acc: 0.6460 - val_loss: 1.3063 - val_acc: 0.6055
#
# Epoch 00025: val_acc did not improve from 0.61481
# Epoch 26/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.1162 - acc: 0.6515 - val_loss: 1.2501 - val_acc: 0.6292
#
# Epoch 00026: val_acc improved from 0.61481 to 0.62923, saving model to model/weights_0.best.hdf5
# Epoch 27/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.1015 - acc: 0.6559 - val_loss: 1.2923 - val_acc: 0.6198
#
# Epoch 00027: val_acc did not improve from 0.62923
# Epoch 28/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.0758 - acc: 0.6646 - val_loss: 1.2836 - val_acc: 0.6156
#
# Epoch 00028: val_acc did not improve from 0.62923
# Epoch 29/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.0563 - acc: 0.6681 - val_loss: 1.3017 - val_acc: 0.6185
#
# Epoch 00029: val_acc did not improve from 0.62923
# Epoch 30/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.0458 - acc: 0.6723 - val_loss: 1.2307 - val_acc: 0.6293
#
# Epoch 00030: val_acc improved from 0.62923 to 0.62931, saving model to model/weights_0.best.hdf5
# Epoch 31/100
# 560/560 [==============================] - 17s 31ms/step - loss: 1.0258 - acc: 0.6807 - val_loss: 1.2333 - val_acc: 0.6304
#
# Epoch 00031: val_acc improved from 0.62931 to 0.63039, saving model to model/weights_0.best.hdf5
# Epoch 32/100
# 560/560 [==============================] - 18s 31ms/step - loss: 1.0147 - acc: 0.6799 - val_loss: 1.1796 - val_acc: 0.6500
#
# Epoch 00032: val_acc improved from 0.63039 to 0.64998, saving model to model/weights_0.best.hdf5
# Epoch 33/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9934 - acc: 0.6860 - val_loss: 1.2640 - val_acc: 0.6225
#
# Epoch 00033: val_acc did not improve from 0.64998
# Epoch 34/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9859 - acc: 0.6929 - val_loss: 1.1958 - val_acc: 0.6391
#
# Epoch 00034: val_acc did not improve from 0.64998
# Epoch 35/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9669 - acc: 0.7001 - val_loss: 1.1637 - val_acc: 0.6523
#
# Epoch 00035: val_acc improved from 0.64998 to 0.65231, saving model to model/weights_0.best.hdf5
# Epoch 36/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9538 - acc: 0.7005 - val_loss: 1.1892 - val_acc: 0.6518
#
# Epoch 00036: val_acc did not improve from 0.65231
# Epoch 37/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9453 - acc: 0.7024 - val_loss: 1.1880 - val_acc: 0.6496
#
# Epoch 00037: val_acc did not improve from 0.65231
# Epoch 38/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9363 - acc: 0.7063 - val_loss: 1.1800 - val_acc: 0.6481
#
# Epoch 00038: val_acc did not improve from 0.65231
# Epoch 39/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9147 - acc: 0.7129 - val_loss: 1.1469 - val_acc: 0.6600
#
# Epoch 00039: val_acc improved from 0.65231 to 0.65997, saving model to model/weights_0.best.hdf5
# Epoch 40/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9166 - acc: 0.7137 - val_loss: 1.1229 - val_acc: 0.6681
#
# Epoch 00040: val_acc improved from 0.65997 to 0.66814, saving model to model/weights_0.best.hdf5
# Epoch 41/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.9022 - acc: 0.7163 - val_loss: 1.1467 - val_acc: 0.6616
#
# Epoch 00041: val_acc did not improve from 0.66814
# Epoch 42/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8919 - acc: 0.7218 - val_loss: 1.1683 - val_acc: 0.6561
#
# Epoch 00042: val_acc did not improve from 0.66814
# Epoch 43/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8814 - acc: 0.7224 - val_loss: 1.1667 - val_acc: 0.6547
#
# Epoch 00043: val_acc did not improve from 0.66814
# Epoch 44/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8648 - acc: 0.7287 - val_loss: 1.1239 - val_acc: 0.6691
#
# Epoch 00044: val_acc improved from 0.66814 to 0.66906, saving model to model/weights_0.best.hdf5
# Epoch 45/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8679 - acc: 0.7268 - val_loss: 1.1335 - val_acc: 0.6628
#
# Epoch 00045: val_acc did not improve from 0.66906
# Epoch 46/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8602 - acc: 0.7312 - val_loss: 1.1472 - val_acc: 0.6620
#
# Epoch 00046: val_acc did not improve from 0.66906
# Epoch 47/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8453 - acc: 0.7344 - val_loss: 1.1696 - val_acc: 0.6578
#
# Epoch 00047: val_acc did not improve from 0.66906
# Epoch 48/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8413 - acc: 0.7378 - val_loss: 1.1296 - val_acc: 0.6661
#
# Epoch 00048: val_acc did not improve from 0.66906
# Epoch 49/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8311 - acc: 0.7397 - val_loss: 1.1223 - val_acc: 0.6701
#
# Epoch 00049: val_acc improved from 0.66906 to 0.67005, saving model to model/weights_0.best.hdf5
# Epoch 50/100
# 560/560 [==============================] - 18s 31ms/step - loss: 0.8171 - acc: 0.7447 - val_loss: 1.0793 - val_acc: 0.6786
#
# Epoch 00050: val_acc improved from 0.67005 to 0.67855, saving model to model/weights_0.best.hdf5
# Epoch 51/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8223 - acc: 0.7411 - val_loss: 1.1223 - val_acc: 0.6708
#
# Epoch 00051: val_acc did not improve from 0.67855
# Epoch 52/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8025 - acc: 0.7464 - val_loss: 1.1215 - val_acc: 0.6729
#
# Epoch 00052: val_acc did not improve from 0.67855
# Epoch 53/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.8094 - acc: 0.7451 - val_loss: 1.0786 - val_acc: 0.6816
#
# Epoch 00053: val_acc improved from 0.67855 to 0.68164, saving model to model/weights_0.best.hdf5
# Epoch 54/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7998 - acc: 0.7504 - val_loss: 1.1064 - val_acc: 0.6782
#
# Epoch 00054: val_acc did not improve from 0.68164
# Epoch 55/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7868 - acc: 0.7533 - val_loss: 1.0791 - val_acc: 0.6861
#
# Epoch 00055: val_acc improved from 0.68164 to 0.68614, saving model to model/weights_0.best.hdf5
# Epoch 56/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7879 - acc: 0.7565 - val_loss: 1.0954 - val_acc: 0.6800
#
# Epoch 00056: val_acc did not improve from 0.68614
# Epoch 57/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7700 - acc: 0.7595 - val_loss: 1.0996 - val_acc: 0.6814
#
# Epoch 00057: val_acc did not improve from 0.68614
# Epoch 58/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7643 - acc: 0.7612 - val_loss: 1.1173 - val_acc: 0.6749
#
# Epoch 00058: val_acc did not improve from 0.68614
# Epoch 59/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7638 - acc: 0.7607 - val_loss: 1.0605 - val_acc: 0.6883
#
# Epoch 00059: val_acc improved from 0.68614 to 0.68830, saving model to model/weights_0.best.hdf5
# Epoch 60/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7651 - acc: 0.7583 - val_loss: 1.0334 - val_acc: 0.7006
#
# Epoch 00060: val_acc improved from 0.68830 to 0.70063, saving model to model/weights_0.best.hdf5
# Epoch 61/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7558 - acc: 0.7627 - val_loss: 1.0498 - val_acc: 0.6972
#
# Epoch 00061: val_acc did not improve from 0.70063
# Epoch 62/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7541 - acc: 0.7635 - val_loss: 1.0532 - val_acc: 0.6941
#
# Epoch 00062: val_acc did not improve from 0.70063
# Epoch 63/100
# 560/560 [==============================] - 18s 31ms/step - loss: 0.7486 - acc: 0.7639 - val_loss: 1.0431 - val_acc: 0.6943
#
# Epoch 00063: val_acc did not improve from 0.70063
# Epoch 64/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7474 - acc: 0.7665 - val_loss: 1.0896 - val_acc: 0.6856
#
# Epoch 00064: val_acc did not improve from 0.70063
# Epoch 65/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7416 - acc: 0.7673 - val_loss: 1.0419 - val_acc: 0.6981
#
# Epoch 00065: val_acc did not improve from 0.70063
# Epoch 66/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7327 - acc: 0.7689 - val_loss: 1.0635 - val_acc: 0.6963
#
# Epoch 00066: val_acc did not improve from 0.70063
# Epoch 67/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7247 - acc: 0.7702 - val_loss: 1.0685 - val_acc: 0.6890
#
# Epoch 00067: val_acc did not improve from 0.70063
# Epoch 68/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7294 - acc: 0.7703 - val_loss: 1.0592 - val_acc: 0.6951
#
# Epoch 00068: val_acc did not improve from 0.70063
# Epoch 69/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7174 - acc: 0.7756 - val_loss: 1.0238 - val_acc: 0.7036
#
# Epoch 00069: val_acc improved from 0.70063 to 0.70363, saving model to model/weights_0.best.hdf5
# Epoch 70/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7167 - acc: 0.7756 - val_loss: 1.0672 - val_acc: 0.6916
#
# Epoch 00070: val_acc did not improve from 0.70363
# Epoch 71/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7065 - acc: 0.7792 - val_loss: 1.0515 - val_acc: 0.6918
#
# Epoch 00071: val_acc did not improve from 0.70363
# Epoch 72/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7085 - acc: 0.7774 - val_loss: 1.0575 - val_acc: 0.6961
#
# Epoch 00072: val_acc did not improve from 0.70363
# Epoch 73/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.7019 - acc: 0.7781 - val_loss: 1.0437 - val_acc: 0.6997
#
# Epoch 00073: val_acc did not improve from 0.70363
# Epoch 74/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6968 - acc: 0.7817 - val_loss: 1.0282 - val_acc: 0.6992
#
# Epoch 00074: val_acc did not improve from 0.70363
# Epoch 75/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6940 - acc: 0.7835 - val_loss: 1.0324 - val_acc: 0.7021
#
# Epoch 00075: val_acc did not improve from 0.70363
# Epoch 76/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6901 - acc: 0.7847 - val_loss: 1.0130 - val_acc: 0.7092
#
# Epoch 00076: val_acc improved from 0.70363 to 0.70922, saving model to model/weights_0.best.hdf5
# Epoch 77/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6887 - acc: 0.7832 - val_loss: 1.0348 - val_acc: 0.7045
#
# Epoch 00077: val_acc did not improve from 0.70922
# Epoch 78/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6867 - acc: 0.7831 - val_loss: 0.9922 - val_acc: 0.7115
#
# Epoch 00078: val_acc improved from 0.70922 to 0.71146, saving model to model/weights_0.best.hdf5
# Epoch 79/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6708 - acc: 0.7899 - val_loss: 1.0039 - val_acc: 0.7112
#
# Epoch 00079: val_acc did not improve from 0.71146
# Epoch 80/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6756 - acc: 0.7892 - val_loss: 1.0862 - val_acc: 0.6887
#
# Epoch 00080: val_acc did not improve from 0.71146
# Epoch 81/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6764 - acc: 0.7875 - val_loss: 0.9957 - val_acc: 0.7143
#
# Epoch 00081: val_acc improved from 0.71146 to 0.71430, saving model to model/weights_0.best.hdf5
# Epoch 82/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6603 - acc: 0.7922 - val_loss: 1.0036 - val_acc: 0.7114
#
# Epoch 00082: val_acc did not improve from 0.71430
# Epoch 83/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6611 - acc: 0.7923 - val_loss: 1.0367 - val_acc: 0.7043
#
# Epoch 00083: val_acc did not improve from 0.71430
# Epoch 84/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6591 - acc: 0.7917 - val_loss: 1.0197 - val_acc: 0.7080
#
# Epoch 00084: val_acc did not improve from 0.71430
# Epoch 85/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6625 - acc: 0.7927 - val_loss: 1.0018 - val_acc: 0.7142
#
# Epoch 00085: val_acc did not improve from 0.71430
# Epoch 86/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6579 - acc: 0.7924 - val_loss: 0.9797 - val_acc: 0.7151
#
# Epoch 00086: val_acc improved from 0.71430 to 0.71513, saving model to model/weights_0.best.hdf5
# Epoch 87/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6597 - acc: 0.7949 - val_loss: 0.9919 - val_acc: 0.7171
#
# Epoch 00087: val_acc improved from 0.71513 to 0.71713, saving model to model/weights_0.best.hdf5
# Epoch 88/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6526 - acc: 0.7956 - val_loss: 1.0645 - val_acc: 0.7026
#
# Epoch 00088: val_acc did not improve from 0.71713
# Epoch 89/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6525 - acc: 0.7943 - val_loss: 0.9732 - val_acc: 0.7211
#
# Epoch 00089: val_acc improved from 0.71713 to 0.72113, saving model to model/weights_0.best.hdf5
# Epoch 90/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6537 - acc: 0.7940 - val_loss: 1.0177 - val_acc: 0.7144
#
# Epoch 00090: val_acc did not improve from 0.72113
# Epoch 91/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6386 - acc: 0.7990 - val_loss: 0.9655 - val_acc: 0.7278
#
# Epoch 00091: val_acc improved from 0.72113 to 0.72780, saving model to model/weights_0.best.hdf5
# Epoch 92/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6391 - acc: 0.7990 - val_loss: 1.0094 - val_acc: 0.7131
#
# Epoch 00092: val_acc did not improve from 0.72780
# Epoch 93/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6425 - acc: 0.7972 - val_loss: 0.9875 - val_acc: 0.7158
#
# Epoch 00093: val_acc did not improve from 0.72780
# Epoch 94/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6394 - acc: 0.7991 - val_loss: 0.9799 - val_acc: 0.7222
#
# Epoch 00094: val_acc did not improve from 0.72780
# Epoch 95/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6303 - acc: 0.8026 - val_loss: 0.9661 - val_acc: 0.7271
#
# Epoch 00095: val_acc did not improve from 0.72780
# Epoch 96/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6298 - acc: 0.8015 - val_loss: 0.9836 - val_acc: 0.7202
#
# Epoch 00096: val_acc did not improve from 0.72780
# Epoch 97/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6278 - acc: 0.8054 - val_loss: 0.9701 - val_acc: 0.7268
#
# Epoch 00097: val_acc did not improve from 0.72780
# Epoch 98/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6246 - acc: 0.8051 - val_loss: 0.9776 - val_acc: 0.7243
#
# Epoch 00098: val_acc did not improve from 0.72780
# Epoch 99/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6233 - acc: 0.8046 - val_loss: 1.0082 - val_acc: 0.7162
#
# Epoch 00099: val_acc did not improve from 0.72780
# Epoch 100/100
# 560/560 [==============================] - 17s 31ms/step - loss: 0.6189 - acc: 0.8055 - val_loss: 0.9647 - val_acc: 0.7285
#
# Epoch 00100: val_acc improved from 0.72780 to 0.72855, saving model to model/weights_0.best.hdf5

# %% [markdown]
# Note: Due to Memory Error like Buffered data was truncated after reaching the output size limit.
# What i did is that Save the model in for example 60th epoch and close current program and run new program and restore saved model and train model from 61 epoch to 120 epoch and save that and close program and repeat this work for your interested epoch
# For this [100,50] three times repeat

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Plot training & validation accuracy values
plt.figure(figsize=(15,6))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# evaluate model
model.evaluate(X_test, y_test)
# Out:
# 12002/12002 [==============================] - 2s 157us/step
# [0.9647183544025171, 0.7285452424595901]

# %% [markdown]
# # Classification Report and Confusion Matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_pred = model.predict_classes(X_test)

# %%
target_name = np.array(df['category'])

# %%
print(classification_report(np.argmax(y_test,axis=1),y_pred,target_names=target_name))
# Out:
#                   precision    recall  f1-score   support
#
#              dog       0.80      0.74      0.77       253
#          rooster       0.17      0.69      0.27       250
#              pig       0.84      0.71      0.77       240
#              cow       0.69      0.69      0.69       242
#             frog       0.94      0.91      0.92       227
#              cat       0.72      0.62      0.67       224
#              hen       0.80      0.75      0.77       254
#          insects       0.85      0.75      0.80       240
#            sheep       0.84      0.77      0.81       240
#             crow       0.85      0.78      0.81       245
#             rain       0.84      1.00      0.91       246
#        sea_waves       0.72      0.92      0.81       229
#   crackling_fire       0.89      0.76      0.82       242
#         crickets       0.87      0.99      0.92       233
#   chirping_birds       0.90      0.78      0.83       233
#      water_drops       0.70      0.56      0.62       241
#             wind       0.64      0.98      0.78       224
#    pouring_water       0.93      0.67      0.78       246
#     toilet_flush       0.90      0.74      0.82       238
#     thunderstorm       0.61      0.89      0.73       232
#      crying_baby       0.75      0.72      0.74       222
#         sneezing       0.68      0.32      0.44       241
#         clapping       0.87      0.84      0.86       230
#        breathing       0.81      0.67      0.73       245
#         coughing       0.68      0.47      0.56       240
#        footsteps       0.79      0.85      0.82       248
#         laughing       0.77      0.53      0.63       243
#   brushing_teeth       0.89      0.84      0.87       236
#          snoring       0.61      0.73      0.67       250
# drinking_sipping       0.74      0.48      0.59       238
#  door_wood_knock       0.48      0.53      0.51       230
#      mouse_click       0.71      0.63      0.67       241
#  keyboard_typing       0.88      0.77      0.82       260
# door_wood_creaks       0.72      0.61      0.66       222
#      can_opening       0.68      0.41      0.51       239
#  washing_machine       0.87      0.79      0.82       248
#   vacuum_cleaner       0.98      0.93      0.95       241
#      clock_alarm       0.95      0.92      0.93       227
#       clock_tick       0.86      0.83      0.84       258
#   glass_breaking       0.69      0.34      0.45       245
#       helicopter       0.74      0.65      0.69       220
#         chainsaw       0.90      0.90      0.90       230
#            siren       0.90      0.94      0.92       262
#         car_horn       0.55      0.63      0.59       240
#           engine       0.91      0.83      0.87       232
#            train       0.71      0.65      0.68       233
#     church_bells       0.83      0.96      0.89       246
#         airplane       0.82      0.74      0.78       250
#        fireworks       0.78      0.72      0.75       263
#         hand_saw       0.94      0.91      0.92       243
#
#        micro avg       0.74      0.74      0.74     12002
#        macro avg       0.78      0.74      0.75     12002
#     weighted avg       0.78      0.74      0.75     12002

# %%
import seaborn as sns
cn_matrix = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
plt.figure(figsize = (40,40))
sns.heatmap(cn_matrix, annot=True)

# %%
# !ls ./model/
# Out:
# weights_0.best.hdf5
